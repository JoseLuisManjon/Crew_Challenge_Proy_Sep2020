# %% [markdown]
# ## API de foursquare

# %%
import json
import requests
import pandas as pd
from pandas.io.json import json_normalize

# %%
# Aqui escribo el path de donde este mi archivo con los token, si esta en la misma carpeta.
json_fullpath = "settings.json"

# %%
with open(json_fullpath, "r+") as outfile:
    json_readed = json.load(outfile)
    # Ahora en json_readed tengo el archivo setting.json para posteriormente poder acceder a los valores de los token llamando a las claves

# %%
GET https://api.foursquare.com/v2/venues/search

# %%
url = 'https://api.foursquare.com/v2/venues/explore'

# más códigos de categorías
# https://developer.foursquare.com/docs/build-with-foursquare/categories/
food = "4d4b7105d754a06374d81259"

# para sacar las coordenadas podrías usar una API pero también...
# https://www.123coordenadas.com/coordinates/

lat = 40.42271305
lon = -3.697609087

# %%
#La forma en la que lo hizo Clara en clase
#Esto es para darle los parametros que me pide la API
params = {"client_id": json_readed["CLIENT"],
  "client_secret": json_readed["API_KEY"],
  "v":"20180323",
  "ll":f'{lat},{lon}', # esto es format y python construye un string con los nombres de las variables
  "section": "food",
  "radius": "2000",
  # options --> food, drinks, coffee, shops, arts, outdoors, sights, trending
  "limit":200
}

# %%
# Como viene en la web de foursqueare
url = 'https://api.foursquare.com/v2/venues/explore'

params = dict(
client_id=json_readed["CLIENT"],
client_secret=json_readed["API_KEY"],
v='20180323',
ll='40.42271305,-3.697609087',
section='food',
radius=2000,
limit=100
)

# %%
resp = requests.get(url=url, params=params)
data = json.loads(resp.text)

# %%
data.keys()
# Out:
# dict_keys([&#39;meta&#39;, &#39;response&#39;])

# %% [markdown]
# Ahora voy uno a uno viendo lo que contienen hasta que encuentre la información que me interesa

# %%
data["meta"]
# La info que contiene meta no me interesa, me centro en response
# Out:
# {&#39;code&#39;: 200, &#39;requestId&#39;: &#39;5f78c0d8aff74850b3987068&#39;}

# %%
data["response"].keys()
# Out:
# dict_keys([&#39;suggestedFilters&#39;, &#39;headerLocation&#39;, &#39;headerFullLocation&#39;, &#39;headerLocationGranularity&#39;, &#39;query&#39;, &#39;totalResults&#39;, &#39;suggestedBounds&#39;, &#39;groups&#39;])

# %%
data["response"]['suggestedFilters']
# No es la info buscada
# Out:
# {&#39;header&#39;: &#39;Tap to show:&#39;, &#39;filters&#39;: [{&#39;name&#39;: &#39;Open now&#39;, &#39;key&#39;: &#39;openNow&#39;}]}

# %%
data["response"]['headerLocation']
# Me da el área de busqueda
# Out:
# &#39;Chueca&#39;

# %%
data["response"]['groups']
# Out:
# 28001&#39;,
#       &#39;cc&#39;: &#39;ES&#39;,
#       &#39;city&#39;: &#39;Madrid&#39;,
#       &#39;state&#39;: &#39;Madrid&#39;,
#       &#39;country&#39;: &#39;España&#39;,
#       &#39;formattedAddress&#39;: [&#39;C. de la Reina, 41&#39;,
#        &#39;28001 Madrid Madrid&#39;,
#        &#39;España&#39;]},
#      &#39;categories&#39;: [{&#39;id&#39;: &#39;4bf58dd8d48988d111941735&#39;,
#        &#39;name&#39;: &#39;Japanese Restaurant&#39;,
#        &#39;pluralName&#39;: &#39;Japanese Restaurants&#39;,
#        &#39;shortName&#39;: &#39;Japanese&#39;,
#        &#39;icon&#39;: {&#39;prefix&#39;: &#39;https://ss3.4sqi.net/img/categories_v2/food/japanese_&#39;,
#         &#39;suffix&#39;: &#39;.png&#39;},
#        &#39;primary&#39;: True}],
#      &#39;verified&#39;: False,
#      &#39;stats&#39;: {&#39;tipCount&#39;: 0,
#       &#39;usersCount&#39;: 0,
#       &#39;checkinsCount&#39;: 0,
#       &#39;visitsCount&#39;: 0},
#      &#39;beenHere&#39;: {&#39;count&#39;: 0,
#       &#39;lastCheckinExpiredAt&#39;: 0,
#       &#39;marked&#39;: False,
#       &#39;unconfirmedCount&#39;: 0},
#      &#39;photos&#39;: {&#39;count&#39;: 0, &#39;groups&#39;: []},
#      &#39;hereNow&#39;: {&#39;count&#39;: 0, &#39;summary&#39;: &#39;Nobody here&#39;, &#39;groups&#39;: []}},
#     &#39;referralId&#39;: &#39;e-3-538ce5df498eb2165bface85-86&#39;},
#    {&#39;reasons&#39;: {&#39;count&#39;: 0,
#      &#39;items&#39;: [{&#39;summary&#39;: &#39;This spot is popular&#39;,
#        &#39;type&#39;: &#39;general&#39;,
#        &#39;reasonName&#39;: &#39;globalInteractionReason&#39;}]},
#     &#39;venue&#39;: {&#39;id&#39;: &#39;53bbb8b3498ee6aee54c9216&#39;,
#      &#39;name&#39;: &#39;Restaurante Bacira&#39;,
#      &#39;contact&#39;: {},
#      &#39;location&#39;: {&#39;address&#39;: &#39;Castillo, 16&#39;,
#       &#39;crossStreet&#39;: &#39;Sagunto&#39;,
#       &#39;lat&#39;: 40.433803250381146,
#       &#39;lng&#39;: -3.6990506779000705,
#       &#39;labeledLatLngs&#39;: [{&#39;label&#39;: &#39;display&#39;,
#         &#39;lat&#39;: 40.433803250381146,
#         &#39;lng&#39;: -3.6990506779000705}],
#       &#39;distance&#39;: 1240,
#       &#39;postalCode&#39;: &#39;28010&#39;,
#       &#39;cc&#39;: &#39;ES&#39;,
#       &#39;neighborhood&#39;: &#39;Chamberí&#39;,
#       &#39;city&#39;: &#39;Madrid&#39;,
#       &#39;state&#39;: &#39;Madrid&#39;,
#       &#39;country&#39;: &#39;España&#39;,
#       &#39;formattedAddress&#39;: [&#39;Castillo, 16 (Sagunto)&#39;,
#        &#39;28010 Madrid Madrid&#39;,
#        &#39;España&#39;]},
#      &#39;categories&#39;: [{&#39;id&#39;: &#39;4bf58dd8d48988d1c4941735&#39;,
#        &#39;name&#39;: &#39;Restaurant&#39;,
#        &#39;pluralName&#39;: &#39;Restaurants&#39;,
#        &#39;shortName&#39;: &#39;Restaurant&#39;,
#        &#39;icon&#39;: {&#39;prefix&#39;: &#39;https://ss3.4sqi.net/img/categories_v2/food/default_&#39;,
#         &#39;suffix&#39;: &#39;.png&#39;},
#        &#39;primary&#39;: True}],
#      &#39;verified&#39;: False,
#      &#39;stats&#39;: {&#39;tipCount&#39;: 0,
#       &#39;usersCount&#39;: 0,
#       &#39;checkinsCount&#39;: 0,
#       &#39;visitsCount&#39;: 0},
#      &#39;beenHere&#39;: {&#39;count&#39;: 0,
#       &#39;lastCheckinExpiredAt&#39;: 0,
#       &#39;marked&#39;: False,
#       &#39;unconfirmedCount&#39;: 0},
#      &#39;photos&#39;: {&#39;count&#39;: 0, &#39;groups&#39;: []},
#      &#39;hereNow&#39;: {&#39;count&#39;: 0, &#39;summary&#39;: &#39;Nobody here&#39;, &#39;groups&#39;: []}},
#     &#39;referralId&#39;: &#39;e-3-53bbb8b3498ee6aee54c9216-87&#39;},
#    {&#39;reasons&#39;: {&#39;count&#39;: 0,
#      &#39;items&#39;: [{&#39;summary&#39;: &#39;This spot is popular&#39;,
#        &#39;type&#39;: &#39;general&#39;,
#        &#39;reasonName&#39;: &#39;globalInteractionReason&#39;}]},
#     &#39;venue&#39;: {&#39;id&#39;: &#39;4be2b9691dd22d7fb69e94bd&#39;,
#      &#39;name&#39;: &#39;La Sanabresa&#39;,
#      &#39;contact&#39;: {},
#      &#39;location&#39;: {&#39;address&#39;: &#39;C. Amor de Dios, 4&#39;,
#       &#39;lat&#39;: 40.41256047164362,
#       &#39;lng&#39;: -3.6984811188512157,
#       &#39;labeledLatLngs&#39;: [{&#39;label&#39;: &#39;display&#39;,
#         &#39;lat&#39;: 40.41256047164362,
#         &#39;lng&#39;: -3.6984811188512157}],
#       &#39;distance&#39;: 1132,
#       &#39;postalCode&#39;: &#39;28014&#39;,
#       &#39;cc&#39;: &#39;ES&#39;,
#       &#39;city&#39;: &#39;Madrid&#39;,
#       &#39;state&#39;: &#39;Madrid&#39;,
#       &#39;country&#39;: &#39;España&#39;,
#       &#39;formattedAddress&#39;: [&#39;C. Amor de Dios, 4&#39;,
#        &#39;28014 Madrid Madrid&#39;,
#        &#39;España&#39;]},
#      &#39;categories&#39;: [{&#39;id&#39;: &#39;4bf58dd8d48988d1c0941735&#39;,
#        &#39;name&#39;: &#39;Mediterranean Restaurant&#39;,
#        &#39;pluralName&#39;: &#39;Mediterranean Restaurants&#39;,
#        &#39;shortName&#39;: &#39;Mediterranean&#39;,
#        &#39;icon&#39;: {&#39;prefix&#39;: &#39;https://ss3.4sqi.net/img/categories_v2/food/mediterranean_&#39;,
#         &#39;suffix&#39;: &#39;.png&#39;},
#        &#39;primary&#39;: True}],
#      &#39;verified&#39;: False,
#      &#39;stats&#39;: {&#39;tipCount&#39;: 0,
#       &#39;usersCount&#39;: 0,
#       &#39;checkinsCount&#39;: 0,
#       &#39;visitsCount&#39;: 0},
#      &#39;beenHere&#39;: {&#39;count&#39;: 0,
#       &#39;lastCheckinExpiredAt&#39;: 0,
#       &#39;marked&#39;: False,
#       &#39;unconfirmedCount&#39;: 0},
#      &#39;photos&#39;: {&#39;count&#39;: 0, &#39;groups&#39;: []},
#      &#39;hereNow&#39;: {&#39;count&#39;: 0, &#39;summary&#39;: &#39;Nobody here&#39;, &#39;groups&#39;: []}},
#     &#39;referralId&#39;: &#39;e-3-4be2b9691dd22d7fb69e94bd-88&#39;},
#    {&#39;reasons&#39;: {&#39;count&#39;: 0,
#      &#39;items&#39;: [{&#39;summary&#39;: &#39;This spot is popular&#39;,
#        &#39;type&#39;: &#39;general&#39;,
#        &#39;reasonName&#39;: &#39;globalInteractionReason&#39;}]},
#     &#39;venue&#39;: {&#39;id&#39;: &#39;4b2cd572f964a520b0c924e3&#39;,
#      &#39;name&#39;: &#39;El Mollete&#39;,
#      &#39;contact&#39;: {},
#      &#39;location&#39;: {&#39;address&#39;: &#39;C. La Bola, 4&#39;,
#       &#39;lat&#39;: 40.419912891328146,
#       &#39;lng&#39;: -3.710502973556587,
#       &#39;labeledLatLngs&#39;: [{&#39;label&#39;: &#39;display&#39;,
#         &#39;lat&#39;: 40.419912891328146,
#         &#39;lng&#39;: -3.710502973556587}],
#       &#39;distance&#39;: 1136,
#       &#39;postalCode&#39;: &#39;28013&#39;,
#       &#39;cc&#39;: &#39;ES&#39;,
#       &#39;city&#39;: &#39;Madrid&#39;,
#       &#39;state&#39;: &#39;Madrid&#39;,
#       &#39;country&#39;: &#39;España&#39;,
#       &#39;formattedAddress&#39;: [&#39;C. La Bola, 4&#39;, &#39;28013 Madrid Madrid&#39;, &#39;España&#39;]},
#      &#39;categories&#39;: [{&#39;id&#39;: &#39;4bf58dd8d48988d1db931735&#39;,
#        &#39;name&#39;: &#39;Tapas Restaurant&#39;,
#        &#39;pluralName&#39;: &#39;Tapas Restaurants&#39;,
#        &#39;shortName&#39;: &#39;Tapas&#39;,
#        &#39;icon&#39;: {&#39;prefix&#39;: &#39;https://ss3.4sqi.net/img/categories_v2/food/tapas_&#39;,
#         &#39;suffix&#39;: &#39;.png&#39;},
#        &#39;primary&#39;: True}],
#      &#39;verified&#39;: False,
#      &#39;stats&#39;: {&#39;tipCount&#39;: 0,
#       &#39;usersCount&#39;: 0,
#       &#39;checkinsCount&#39;: 0,
#       &#39;visitsCount&#39;: 0},
#      &#39;beenHere&#39;: {&#39;count&#39;: 0,
#       &#39;lastCheckinExpiredAt&#39;: 0,
#       &#39;marked&#39;: False,
#       &#39;unconfirmedCount&#39;: 0},
#      &#39;photos&#39;: {&#39;count&#39;: 0, &#39;groups&#39;: []},
#      &#39;hereNow&#39;: {&#39;count&#39;: 0, &#39;summary&#39;: &#39;Nobody here&#39;, &#39;groups&#39;: []}},
#     &#39;referralId&#39;: &#39;e-3-4b2cd572f964a520b0c924e3-89&#39;},
#    {&#39;reasons&#39;: {&#39;count&#39;: 0,
#      &#39;items&#39;: [{&#39;summary&#39;: &#39;This spot is popular&#39;,
#        &#39;type&#39;: &#39;general&#39;,
#        &#39;reasonName&#39;: &#39;globalInteractionReason&#39;}]},
#     &#39;venue&#39;: {&#39;id&#39;: &#39;531dac8a498e60048308cff3&#39;,
#      &#39;name&#39;: &#39;GramaBar&#39;,
#      &#39;contact&#39;: {},
#      &#39;location&#39;: {&#39;address&#39;: &#39;C. Preciados, 40&#39;,
#       &#39;lat&#39;: 40.41976873108436,
#       &#39;lng&#39;: -3.7071476250900037,
#       &#39;labeledLatLngs&#39;: [{&#39;label&#39;: &#39;display&#39;,
#         &#39;lat&#39;: 40.41976873108436,
#         &#39;lng&#39;: -3.7071476250900037}],
#       &#39;distance&#39;: 872,
#       &#39;postalCode&#39;: &#39;28013&#39;,
#       &#39;cc&#39;: &#39;ES&#39;,
#       &#39;city&#39;: &#39;Madrid&#39;,
#       &#39;state&#39;: &#39;Madrid&#39;,
#       &#39;country&#39;: &#39;España&#39;,
#       &#39;formattedAddress&#39;: [&#39;C. Preciados, 40&#39;,
#        &#39;28013 Madrid Madrid&#39;,
#        &#39;España&#39;]},
#      &#39;categories&#39;: [{&#39;id&#39;: &#39;4bf58dd8d48988d155941735&#39;,
#        &#39;name&#39;: &#39;Gastropub&#39;,
#        &#39;pluralName&#39;: &#39;Gastropubs&#39;,
#        &#39;shortName&#39;: &#39;Gastropub&#39;,
#        &#39;icon&#39;: {&#39;prefix&#39;: &#39;https://ss3.4sqi.net/img/categories_v2/food/gastropub_&#39;,
#         &#39;suffix&#39;: &#39;.png&#39;},
#        &#39;primary&#39;: True}],
#      &#39;verified&#39;: True,
#      &#39;stats&#39;: {&#39;tipCount&#39;: 0,
#       &#39;usersCount&#39;: 0,
#       &#39;checkinsCount&#39;: 0,
#       &#39;visitsCount&#39;: 0},
#      &#39;beenHere&#39;: {&#39;count&#39;: 0,
#       &#39;lastCheckinExpiredAt&#39;: 0,
#       &#39;marked&#39;: False,
#       &#39;unconfirmedCount&#39;: 0},
#      &#39;photos&#39;: {&#39;count&#39;: 0, &#39;groups&#39;: []},
#      &#39;venuePage&#39;: {&#39;id&#39;: &#39;89411054&#39;},
#      &#39;hereNow&#39;: {&#39;count&#39;: 0, &#39;summary&#39;: &#39;Nobody here&#39;, &#39;groups&#39;: []}},
#     &#39;referralId&#39;: &#39;e-3-531dac8a498e60048308cff3-90&#39;},
#    {&#39;reasons&#39;: {&#39;count&#39;: 0,
#      &#39;items&#39;: [{&#39;summary&#39;: &#39;This spot is popular&#39;,
#        &#39;type&#39;: &#39;general&#39;,
#        &#39;reasonName&#39;: &#39;globalInteractionReason&#39;}]},
#     &#39;venue&#39;: {&#39;id&#39;: &#39;4c98adf707916dcb52faed1b&#39;,
#      &#39;name&#39;: &#39;La Tragantúa&#39;,
#      &#39;contact&#39;: {},
#      &#39;location&#39;: {&#39;address&#39;: &#39;C. Verónica, 4&#39;,
#       &#39;crossStreet&#39;: &#39;C. Fúcar&#39;,
#       &#39;lat&#39;: 40.41184555400155,
#       &#39;lng&#39;: -3.6954076239854836,
#       &#39;labeledLatLngs&#39;: [{&#39;label&#39;: &#39;display&#39;,
#         &#39;lat&#39;: 40.41184555400155,
#         &#39;lng&#39;: -3.6954076239854836}],
#       &#39;distance&#39;: 1224,
#       &#39;postalCode&#39;: &#39;28014&#39;,
#       &#39;cc&#39;: &#39;ES&#39;,
#       &#39;city&#39;: &#39;Madrid&#39;,
#       &#39;state&#39;: &#39;Madrid&#39;,
#       &#39;country&#39;: &#39;España&#39;,
#       &#39;formattedAddress&#39;: [&#39;C. Verónica, 4 (C. Fúcar)&#39;,
#        &#39;28014 Madrid Madrid&#39;,
#        &#39;España&#39;]},
#      &#39;categories&#39;: [{&#39;id&#39;: &#39;4bf58dd8d48988d150941735&#39;,
#        &#39;name&#39;: &#39;Spanish Restaurant&#39;,
#        &#39;pluralName&#39;: &#39;Spanish Restaurants&#39;,
#        &#39;shortName&#39;: &#39;Spanish&#39;,
#        &#39;icon&#39;: {&#39;prefix&#39;: &#39;https://ss3.4sqi.net/img/categories_v2/food/spanish_&#39;,
#         &#39;suffix&#39;: &#39;.png&#39;},
#        &#39;primary&#39;: True}],
#      &#39;verified&#39;: False,
#      &#39;stats&#39;: {&#39;tipCount&#39;: 0,
#       &#39;usersCount&#39;: 0,
#       &#39;checkinsCount&#39;: 0,
#       &#39;visitsCount&#39;: 0},
#      &#39;beenHere&#39;: {&#39;count&#39;: 0,
#       &#39;lastCheckinExpiredAt&#39;: 0,
#       &#39;marked&#39;: False,
#       &#39;unconfirmedCount&#39;: 0},
#      &#39;photos&#39;: {&#39;count&#39;: 0, &#39;groups&#39;: []},
#      &#39;hereNow&#39;: {&#39;count&#39;: 0, &#39;summary&#39;: &#39;Nobody here&#39;, &#39;groups&#39;: []}},
#     &#39;referralId&#39;: &#39;e-3-4c98adf707916dcb52faed1b-91&#39;},
#    {&#39;reasons&#39;: {&#39;count&#39;: 0,
#      &#39;items&#39;: [{&#39;summary&#39;: &#39;This spot is popular&#39;,
#        &#39;type&#39;: &#39;general&#39;,
#        &#39;reasonName&#39;: &#39;globalInteractionReason&#39;}]},
#     &#39;venue&#39;: {&#39;id&#39;: &#39;5a6db4f141868670dbfe3e89&#39;,
#      &#39;name&#39;: &#39;Delish Vegan Doughnuts&#39;,
#      &#39;contact&#39;: {},
#      &#39;location&#39;: {&#39;address&#39;: &#39;3 Calle del Cristo&#39;,
#       &#39;lat&#39;: 40.42694912512703,
#       &#39;lng&#39;: -3.7100989203246573,
#       &#39;labeledLatLngs&#39;: [{&#39;label&#39;: &#39;display&#39;,
#         &#39;lat&#39;: 40.42694912512703,
#         &#39;lng&#39;: -3.7100989203246573}],
#       &#39;distance&#39;: 1158,
#       &#39;postalCode&#39;: &#39;28015&#39;,
#       &#39;cc&#39;: &#39;ES&#39;,
#       &#39;neighborhood&#39;: &#39;Universidad&#39;,
#       &#39;city&#39;: &#39;Madrid&#39;,
#       &#39;state&#39;: &#39;Madrid&#39;,
#       &#39;country&#39;: &#39;España&#39;,
#       &#39;formattedAddress&#39;: [&#39;3 Calle del Cristo&#39;,
#        &#39;28015 Madrid Madrid&#39;,
#        &#39;España&#39;]},
#      &#39;categories&#39;: [{&#39;id&#39;: &#39;4bf58dd8d48988d148941735&#39;,
#        &#39;name&#39;: &#39;Donut Shop&#39;,
#        &#39;pluralName&#39;: &#39;Donut Shops&#39;,
#        &#39;shortName&#39;: &#39;Donuts&#39;,
#        &#39;icon&#39;: {&#39;prefix&#39;: &#39;https://ss3.4sqi.net/img/categories_v2/food/donuts_&#39;,
#         &#39;suffix&#39;: &#39;.png&#39;},
#        &#39;primary&#39;: True}],
#      &#39;verified&#39;: False,
#      &#39;stats&#39;: {&#39;tipCount&#39;: 0,
#       &#39;usersCount&#39;: 0,
#       &#39;checkinsCount&#39;: 0,
#       &#39;visitsCount&#39;: 0},
#      &#39;beenHere&#39;: {&#39;count&#39;: 0,
#       &#39;lastCheckinExpiredAt&#39;: 0,
#       &#39;marked&#39;: False,
#       &#39;unconfirmedCount&#39;: 0},
#      &#39;photos&#39;: {&#39;count&#39;: 0, &#39;groups&#39;: []},
#      &#39;hereNow&#39;: {&#39;count&#39;: 0, &#39;summary&#39;: &#39;Nobody here&#39;, &#39;groups&#39;: []}},
#     &#39;referralId&#39;: &#39;e-3-5a6db4f141868670dbfe3e89-92&#39;},
#    {&#39;reasons&#39;: {&#39;count&#39;: 0,
#      &#39;items&#39;: [{&#39;summary&#39;: &#39;This spot is popular&#39;,
#        &#39;type&#39;: &#39;general&#39;,
#        &#39;reasonName&#39;: &#39;globalInteractionReason&#39;}]},
#     &#39;venue&#39;: {&#39;id&#39;: &#39;54b51437498e8924f2766f00&#39;,
#      &#39;name&#39;: &#39;Salón Cascabel&#39;,
#      &#39;contact&#39;: {},
#      &#39;location&#39;: {&#39;address&#39;: &#39;Serrano 52, 7 planta&#39;,
#       &#39;crossStreet&#39;: &#39;Ayala&#39;,
#       &#39;lat&#39;: 40.427699920608354,
#       &#39;lng&#39;: -3.6872659298342922,
#       &#39;labeledLatLngs&#39;: [{&#39;label&#39;: &#39;display&#39;,
#         &#39;lat&#39;: 40.427699920608354,
#         &#39;lng&#39;: -3.6872659298342922}],
#       &#39;distance&#39;: 1037,
#       &#39;postalCode&#39;: &#39;28001&#39;,
#       &#39;cc&#39;: &#39;ES&#39;,
#       &#39;city&#39;: &#39;Madrid Centro, Madrid&#39;,
#       &#39;state&#39;: &#39;Madrid&#39;,
#       &#39;country&#39;: &#39;España&#39;,
#       &#39;formattedAddress&#39;: [&#39;Serrano 52, 7 planta (Ayala)&#39;,
#        &#39;28001 Madrid Centro Madrid&#39;,
#        &#39;España&#39;]},
#      &#39;categories&#39;: [{&#39;id&#39;: &#39;4bf58dd8d48988d1c1941735&#39;,
#        &#39;name&#39;: &#39;Mexican Restaurant&#39;,
#        &#39;pluralName&#39;: &#39;Mexican Restaurants&#39;,
#        &#39;shortName&#39;: &#39;Mexican&#39;,
#        &#39;icon&#39;: {&#39;prefix&#39;: &#39;https://ss3.4sqi.net/img/categories_v2/food/mexican_&#39;,
#         &#39;suffix&#39;: &#39;.png&#39;},
#        &#39;primary&#39;: True}],
#      &#39;verified&#39;: False,
#      &#39;stats&#39;: {&#39;tipCount&#39;: 0,
#       &#39;usersCount&#39;: 0,
#       &#39;checkinsCount&#39;: 0,
#       &#39;visitsCount&#39;: 0},
#      &#39;beenHere&#39;: {&#39;count&#39;: 0,
#       &#39;lastCheckinExpiredAt&#39;: 0,
#       &#39;marked&#39;: False,
#       &#39;unconfirmedCount&#39;: 0},
#      &#39;photos&#39;: {&#39;count&#39;: 0, &#39;groups&#39;: []},
#      &#39;hereNow&#39;: {&#39;count&#39;: 0, &#39;summary&#39;: &#39;Nobody here&#39;, &#39;groups&#39;: []}},
#     &#39;referralId&#39;: &#39;e-3-54b51437498e8924f2766f00-93&#39;},
#    {&#39;reasons&#39;: {&#39;count&#39;: 0,
#      &#39;items&#39;: [{&#39;summary&#39;: &#39;This spot is popular&#39;,
#        &#39;type&#39;: &#39;general&#39;,
#        &#39;reasonName&#39;: &#39;globalInteractionReason&#39;}]},
#     &#39;venue&#39;: {&#39;id&#39;: &#39;5a2454e3fd16bb353b4ec264&#39;,
#      &#39;name&#39;: &#39;La Esperanza&#39;,
#      &#39;contact&#39;: {},
#      &#39;location&#39;: {&#39;address&#39;: &#39;C. Torrecilla del Leal, 3&#39;,
#       &#39;lat&#39;: 40.41149716350271,
#       &#39;lng&#39;: -3.6994495684985402,
#       &#39;labeledLatLngs&#39;: [{&#39;label&#39;: &#39;display&#39;,
#         &#39;lat&#39;: 40.41149716350271,
#         &#39;lng&#39;: -3.6994495684985402}],
#       &#39;distance&#39;: 1258,
#       &#39;postalCode&#39;: &#39;28012&#39;,
#       &#39;cc&#39;: &#39;ES&#39;,
#       &#39;city&#39;: &#39;Madrid&#39;,
#       &#39;state&#39;: &#39;Madrid&#39;,
#       &#39;country&#39;: &#39;España&#39;,
#       &#39;formattedAddress&#39;: [&#39;C. Torrecilla del Leal, 3&#39;,
#        &#39;28012 Madrid Madrid&#39;,
#        &#39;España&#39;]},
#      &#39;categories&#39;: [{&#39;id&#39;: &#39;4bf58dd8d48988d1c0941735&#39;,
#        &#39;name&#39;: &#39;Mediterranean Restaurant&#39;,
#        &#39;pluralName&#39;: &#39;Mediterranean Restaurants&#39;,
#        &#39;shortName&#39;: &#39;Mediterranean&#39;,
#        &#39;icon&#39;: {&#39;prefix&#39;: &#39;https://ss3.4sqi.net/img/categories_v2/food/mediterranean_&#39;,
#         &#39;suffix&#39;: &#39;.png&#39;},
#        &#39;primary&#39;: True}],
#      &#39;verified&#39;: False,
#      &#39;stats&#39;: {&#39;tipCount&#39;: 0,
#       &#39;usersCount&#39;: 0,
#       &#39;checkinsCount&#39;: 0,
#       &#39;visitsCount&#39;: 0},
#      &#39;beenHere&#39;: {&#39;count&#39;: 0,
#       &#39;lastCheckinExpiredAt&#39;: 0,
#       &#39;marked&#39;: False,
#       &#39;unconfirmedCount&#39;: 0},
#      &#39;photos&#39;: {&#39;count&#39;: 0, &#39;groups&#39;: []},
#      &#39;hereNow&#39;: {&#39;count&#39;: 0, &#39;summary&#39;: &#39;Nobody here&#39;, &#39;groups&#39;: []}},
#     &#39;referralId&#39;: &#39;e-3-5a2454e3fd16bb353b4ec264-94&#39;},
#    {&#39;reasons&#39;: {&#39;count&#39;: 0,
#      &#39;items&#39;: [{&#39;summary&#39;: &#39;This spot is popular&#39;,
#        &#39;type&#39;: &#39;general&#39;,
#        &#39;reasonName&#39;: &#39;globalInteractionReason&#39;}]},
#     &#39;venue&#39;: {&#39;id&#39;: &#39;4b7bf438f964a52096752fe3&#39;,
#      &#39;name&#39;: &#39;El Senador&#39;,
#      &#39;contact&#39;: {},
#      &#39;location&#39;: {&#39;address&#39;: &#39;Plaza de La Marina Española, 2&#39;,
#       &#39;lat&#39;: 40.42076966674159,
#       &#39;lng&#39;: -3.7114585151950705,
#       &#39;labeledLatLngs&#39;: [{&#39;label&#39;: &#39;display&#39;,
#         &#39;lat&#39;: 40.42076966674159,
#         &#39;lng&#39;: -3.7114585151950705}],
#       &#39;distance&#39;: 1193,
#       &#39;postalCode&#39;: &#39;28013&#39;,
#       &#39;cc&#39;: &#39;ES&#39;,
#       &#39;city&#39;: &#39;Madrid&#39;,
#       &#39;state&#39;: &#39;Madrid&#39;,
#       &#39;country&#39;: &#39;España&#39;,
#       &#39;formattedAddress&#39;: [&#39;Plaza de La Marina Española, 2&#39;,
#        &#39;28013 Madrid Madrid&#39;,
#        &#39;España&#39;]},
#      &#39;categories&#39;: [{&#39;id&#39;: &#39;4bf58dd8d48988d150941735&#39;,
#        &#39;name&#39;: &#39;Spanish Restaurant&#39;,
#        &#39;pluralName&#39;: &#39;Spanish Restaurants&#39;,
#        &#39;shortName&#39;: &#39;Spanish&#39;,
#        &#39;icon&#39;: {&#39;prefix&#39;: &#39;https://ss3.4sqi.net/img/categories_v2/food/spanish_&#39;,
#         &#39;suffix&#39;: &#39;.png&#39;},
#        &#39;primary&#39;: True}],
#      &#39;verified&#39;: False,
#      &#39;stats&#39;: {&#39;tipCount&#39;: 0,
#       &#39;usersCount&#39;: 0,
#       &#39;checkinsCount&#39;: 0,
#       &#39;visitsCount&#39;: 0},
#      &#39;beenHere&#39;: {&#39;count&#39;: 0,
#       &#39;lastCheckinExpiredAt&#39;: 0,
#       &#39;marked&#39;: False,
#       &#39;unconfirmedCount&#39;: 0},
#      &#39;photos&#39;: {&#39;count&#39;: 0, &#39;groups&#39;: []},
#      &#39;hereNow&#39;: {&#39;count&#39;: 0, &#39;summary&#39;: &#39;Nobody here&#39;, &#39;groups&#39;: []}},
#     &#39;referralId&#39;: &#39;e-3-4b7bf438f964a52096752fe3-95&#39;},
#    {&#39;reasons&#39;: {&#39;count&#39;: 0,
#      &#39;items&#39;: [{&#39;summary&#39;: &#39;This spot is popular&#39;,
#        &#39;type&#39;: &#39;general&#39;,
#        &#39;reasonName&#39;: &#39;globalInteractionReason&#39;}]},
#     &#39;venue&#39;: {&#39;id&#39;: &#39;4bbf8bbaf8219c74752ab010&#39;,
#      &#39;name&#39;: &#39;El Sur&#39;,
#      &#39;contact&#39;: {},
#      &#39;location&#39;: {&#39;address&#39;: &#39;C. Torrecilla del Leal, 12&#39;,
#       &#39;lat&#39;: 40.411135324189495,
#       &#39;lng&#39;: -3.699521331741858,
#       &#39;labeledLatLngs&#39;: [{&#39;label&#39;: &#39;display&#39;,
#         &#39;lat&#39;: 40.411135324189495,
#         &#39;lng&#39;: -3.699521331741858}],
#       &#39;distance&#39;: 1298,
#       &#39;postalCode&#39;: &#39;28012&#39;,
#       &#39;cc&#39;: &#39;ES&#39;,
#       &#39;city&#39;: &#39;Madrid&#39;,
#       &#39;state&#39;: &#39;Madrid&#39;,
#       &#39;country&#39;: &#39;España&#39;,
#       &#39;formattedAddress&#39;: [&#39;C. Torrecilla del Leal, 12&#39;,
#        &#39;28012 Madrid Madrid&#39;,
#        &#39;España&#39;]},
#      &#39;categories&#39;: [{&#39;id&#39;: &#39;4bf58dd8d48988d1c4941735&#39;,
#        &#39;name&#39;: &#39;Restaurant&#39;,
#        &#39;pluralName&#39;: &#39;Restaurants&#39;,
#        &#39;shortName&#39;: &#39;Restaurant&#39;,
#        &#39;icon&#39;: {&#39;prefix&#39;: &#39;https://ss3.4sqi.net/img/categories_v2/food/default_&#39;,
#         &#39;suffix&#39;: &#39;.png&#39;},
#        &#39;primary&#39;: True}],
#      &#39;verified&#39;: False,
#      &#39;stats&#39;: {&#39;tipCount&#39;: 0,
#       &#39;usersCount&#39;: 0,
#       &#39;checkinsCount&#39;: 0,
#       &#39;visitsCount&#39;: 0},
#      &#39;beenHere&#39;: {&#39;count&#39;: 0,
#       &#39;lastCheckinExpiredAt&#39;: 0,
#       &#39;marked&#39;: False,
#       &#39;unconfirmedCount&#39;: 0},
#      &#39;photos&#39;: {&#39;count&#39;: 0, &#39;groups&#39;: []},
#      &#39;hereNow&#39;: {&#39;count&#39;: 0, &#39;summary&#39;: &#39;Nobody here&#39;, &#39;groups&#39;: []}},
#     &#39;referralId&#39;: &#39;e-3-4bbf8bbaf8219c74752ab010-96&#39;},
#    {&#39;reasons&#39;: {&#39;count&#39;: 0,
#      &#39;items&#39;: [{&#39;summary&#39;: &#39;This spot is popular&#39;,
#        &#39;type&#39;: &#39;general&#39;,
#        &#39;reasonName&#39;: &#39;globalInteractionReason&#39;}]},
#     &#39;venue&#39;: {&#39;id&#39;: &#39;52d96b74498e34079b6bbf2a&#39;,
#      &#39;name&#39;: &#39;MORE&#39;,
#      &#39;contact&#39;: {},
#      &#39;location&#39;: {&#39;address&#39;: &#39;Jorge Juan,25&#39;,
#       &#39;crossStreet&#39;: &#39;Velázquez&#39;,
#       &#39;lat&#39;: 40.42388443976496,
#       &#39;lng&#39;: -3.6838091221418963,
#       &#39;labeledLatLngs&#39;: [{&#39;label&#39;: &#39;display&#39;,
#         &#39;lat&#39;: 40.42388443976496,
#         &#39;lng&#39;: -3.6838091221418963}],
#       &#39;distance&#39;: 1176,
#       &#39;postalCode&#39;: &#39;28001&#39;,
#       &#39;cc&#39;: &#39;ES&#39;,
#       &#39;city&#39;: &#39;Madrid&#39;,
#       &#39;state&#39;: &#39;Madrid&#39;,
#       &#39;country&#39;: &#39;España&#39;,
#       &#39;formattedAddress&#39;: [&#39;Jorge Juan,25 (Velázquez)&#39;,
#        &#39;28001 Madrid Madrid&#39;,
#        &#39;España&#39;]},
#      &#39;categories&#39;: [{&#39;id&#39;: &#39;4bf58dd8d48988d1c4941735&#39;,
#        &#39;name&#39;: &#39;Restaurant&#39;,
#        &#39;pluralName&#39;: &#39;Restaurants&#39;,
#        &#39;shortName&#39;: &#39;Restaurant&#39;,
#        &#39;icon&#39;: {&#39;prefix&#39;: &#39;https://ss3.4sqi.net/img/categories_v2/food/default_&#39;,
#         &#39;suffix&#39;: &#39;.png&#39;},
#        &#39;primary&#39;: True}],
#      &#39;verified&#39;: False,
#      &#39;stats&#39;: {&#39;tipCount&#39;: 0,
#       &#39;usersCount&#39;: 0,
#       &#39;checkinsCount&#39;: 0,
#       &#39;visitsCount&#39;: 0},
#      &#39;beenHere&#39;: {&#39;count&#39;: 0,
#       &#39;lastCheckinExpiredAt&#39;: 0,
#       &#39;marked&#39;: False,
#       &#39;unconfirmedCount&#39;: 0},
#      &#39;photos&#39;: {&#39;count&#39;: 0, &#39;groups&#39;: []},
#      &#39;hereNow&#39;: {&#39;count&#39;: 0, &#39;summary&#39;: &#39;Nobody here&#39;, &#39;groups&#39;: []}},
#     &#39;referralId&#39;: &#39;e-3-52d96b74498e34079b6bbf2a-97&#39;},
#    {&#39;reasons&#39;: {&#39;count&#39;: 0,
#      &#39;items&#39;: [{&#39;summary&#39;: &#39;This spot is popular&#39;,
#        &#39;type&#39;: &#39;general&#39;,
#        &#39;reasonName&#39;: &#39;globalInteractionReason&#39;}]},
#     &#39;venue&#39;: {&#39;id&#39;: &#39;51335848e4b0cfae58777e98&#39;,
#      &#39;name&#39;: &#39;El Cielo&#39;,
#      &#39;contact&#39;: {},
#      &#39;location&#39;: {&#39;address&#39;: &#39;Calle Fúcar, 4&#39;,
#       &#39;lat&#39;: 40.4124737354003,
#       &#39;lng&#39;: -3.6956884720810095,
#       &#39;labeledLatLngs&#39;: [{&#39;label&#39;: &#39;display&#39;,
#         &#39;lat&#39;: 40.4124737354003,
#         &#39;lng&#39;: -3.6956884720810095}],
#       &#39;distance&#39;: 1151,
#       &#39;postalCode&#39;: &#39;28014&#39;,
#       &#39;cc&#39;: &#39;ES&#39;,
#       &#39;city&#39;: &#39;Madrid&#39;,
#       &#39;state&#39;: &#39;Madrid&#39;,
#       &#39;country&#39;: &#39;España&#39;,
#       &#39;formattedAddress&#39;: [&#39;Calle Fúcar, 4&#39;, &#39;28014 Madrid Madrid&#39;, &#39;España&#39;]},
#      &#39;categories&#39;: [{&#39;id&#39;: &#39;4bf58dd8d48988d1cb941735&#39;,
#        &#39;name&#39;: &#39;Food Truck&#39;,
#        &#39;pluralName&#39;: &#39;Food Trucks&#39;,
#        &#39;shortName&#39;: &#39;Food Truck&#39;,
#        &#39;icon&#39;: {&#39;prefix&#39;: &#39;https://ss3.4sqi.net/img/categories_v2/food/streetfood_&#39;,
#         &#39;suffix&#39;: &#39;.png&#39;},
#        &#39;primary&#39;: True}],
#      &#39;verified&#39;: False,
#      &#39;stats&#39;: {&#39;tipCount&#39;: 0,
#       &#39;usersCount&#39;: 0,
#       &#39;checkinsCount&#39;: 0,
#       &#39;visitsCount&#39;: 0},
#      &#39;beenHere&#39;: {&#39;count&#39;: 0,
#       &#39;lastCheckinExpiredAt&#39;: 0,
#       &#39;marked&#39;: False,
#       &#39;unconfirmedCount&#39;: 0},
#      &#39;photos&#39;: {&#39;count&#39;: 0, &#39;groups&#39;: []},
#      &#39;hereNow&#39;: {&#39;count&#39;: 0, &#39;summary&#39;: &#39;Nobody here&#39;, &#39;groups&#39;: []}},
#     &#39;referralId&#39;: &#39;e-3-51335848e4b0cfae58777e98-98&#39;},
#    {&#39;reasons&#39;: {&#39;count&#39;: 0,
#      &#39;items&#39;: [{&#39;summary&#39;: &#39;This spot is popular&#39;,
#        &#39;type&#39;: &#39;general&#39;,
#        &#39;reasonName&#39;: &#39;globalInteractionReason&#39;}]},
#     &#39;venue&#39;: {&#39;id&#39;: &#39;525ad2cc498e875d748818fd&#39;,
#      &#39;name&#39;: &#39;Federal Café&#39;,
#      &#39;contact&#39;: {},
#      &#39;location&#39;: {&#39;address&#39;: &#39;Pl. de las Comendadoras, 9&#39;,
#       &#39;crossStreet&#39;: &#39;C. Amaniel, 30&#39;,
#       &#39;lat&#39;: 40.427173427148695,
#       &#39;lng&#39;: -3.7092873110522837,
#       &#39;labeledLatLngs&#39;: [{&#39;label&#39;: &#39;display&#39;,
#         &#39;lat&#39;: 40.427173427148695,
#         &#39;lng&#39;: -3.7092873110522837}],
#       &#39;distance&#39;: 1107,
#       &#39;postalCode&#39;: &#39;28015&#39;,
#       &#39;cc&#39;: &#39;ES&#39;,
#       &#39;city&#39;: &#39;Madrid&#39;,
#       &#39;state&#39;: &#39;Madrid&#39;,
#       &#39;country&#39;: &#39;España&#39;,
#       &#39;formattedAddress&#39;: [&#39;Pl. de las Comendadoras, 9 (C. Amaniel, 30)&#39;,
#        &#39;28015 Madrid Madrid&#39;,
#        &#39;España&#39;]},
#      &#39;categories&#39;: [{&#39;id&#39;: &#39;4bf58dd8d48988d16d941735&#39;,
#        &#39;name&#39;: &#39;Café&#39;,
#        &#39;pluralName&#39;: &#39;Cafés&#39;,
#        &#39;shortName&#39;: &#39;Café&#39;,
#        &#39;icon&#39;: {&#39;prefix&#39;: &#39;https://ss3.4sqi.net/img/categories_v2/food/cafe_&#39;,
#         &#39;suffix&#39;: &#39;.png&#39;},
#        &#39;primary&#39;: True}],
#      &#39;verified&#39;: False,
#      &#39;stats&#39;: {&#39;tipCount&#39;: 0,
#       &#39;usersCount&#39;: 0,
#       &#39;checkinsCount&#39;: 0,
#       &#39;visitsCount&#39;: 0},
#      &#39;beenHere&#39;: {&#39;count&#39;: 0,
#       &#39;lastCheckinExpiredAt&#39;: 0,
#       &#39;marked&#39;: False,
#       &#39;unconfirmedCount&#39;: 0},
#      &#39;photos&#39;: {&#39;count&#39;: 0, &#39;groups&#39;: []},
#      &#39;hereNow&#39;: {&#39;count&#39;: 0, &#39;summary&#39;: &#39;Nobody here&#39;, &#39;groups&#39;: []}},
#     &#39;referralId&#39;: &#39;e-3-525ad2cc498e875d748818fd-99&#39;}]}]

# %%
data["response"]['groups'][0]
# Out:
#  &#39;referralId&#39;: &#39;e-3-4f2d2e4ae4b0124ab827520d-85&#39;},
#   {&#39;reasons&#39;: {&#39;count&#39;: 0,
#     &#39;items&#39;: [{&#39;summary&#39;: &#39;This spot is popular&#39;,
#       &#39;type&#39;: &#39;general&#39;,
#       &#39;reasonName&#39;: &#39;globalInteractionReason&#39;}]},
#    &#39;venue&#39;: {&#39;id&#39;: &#39;538ce5df498eb2165bface85&#39;,
#     &#39;name&#39;: &#39;Yakitoro&#39;,
#     &#39;contact&#39;: {},
#     &#39;location&#39;: {&#39;address&#39;: &#39;C. de la Reina, 41&#39;,
#      &#39;lat&#39;: 40.419647701387746,
#      &#39;lng&#39;: -3.697201837743589,
#      &#39;labeledLatLngs&#39;: [{&#39;label&#39;: &#39;display&#39;,
#        &#39;lat&#39;: 40.419647701387746,
#        &#39;lng&#39;: -3.697201837743589}],
#      &#39;distance&#39;: 342,
#      &#39;postalCode&#39;: &#39;28001&#39;,
#      &#39;cc&#39;: &#39;ES&#39;,
#      &#39;city&#39;: &#39;Madrid&#39;,
#      &#39;state&#39;: &#39;Madrid&#39;,
#      &#39;country&#39;: &#39;España&#39;,
#      &#39;formattedAddress&#39;: [&#39;C. de la Reina, 41&#39;,
#       &#39;28001 Madrid Madrid&#39;,
#       &#39;España&#39;]},
#     &#39;categories&#39;: [{&#39;id&#39;: &#39;4bf58dd8d48988d111941735&#39;,
#       &#39;name&#39;: &#39;Japanese Restaurant&#39;,
#       &#39;pluralName&#39;: &#39;Japanese Restaurants&#39;,
#       &#39;shortName&#39;: &#39;Japanese&#39;,
#       &#39;icon&#39;: {&#39;prefix&#39;: &#39;https://ss3.4sqi.net/img/categories_v2/food/japanese_&#39;,
#        &#39;suffix&#39;: &#39;.png&#39;},
#       &#39;primary&#39;: True}],
#     &#39;verified&#39;: False,
#     &#39;stats&#39;: {&#39;tipCount&#39;: 0,
#      &#39;usersCount&#39;: 0,
#      &#39;checkinsCount&#39;: 0,
#      &#39;visitsCount&#39;: 0},
#     &#39;beenHere&#39;: {&#39;count&#39;: 0,
#      &#39;lastCheckinExpiredAt&#39;: 0,
#      &#39;marked&#39;: False,
#      &#39;unconfirmedCount&#39;: 0},
#     &#39;photos&#39;: {&#39;count&#39;: 0, &#39;groups&#39;: []},
#     &#39;hereNow&#39;: {&#39;count&#39;: 0, &#39;summary&#39;: &#39;Nobody here&#39;, &#39;groups&#39;: []}},
#    &#39;referralId&#39;: &#39;e-3-538ce5df498eb2165bface85-86&#39;},
#   {&#39;reasons&#39;: {&#39;count&#39;: 0,
#     &#39;items&#39;: [{&#39;summary&#39;: &#39;This spot is popular&#39;,
#       &#39;type&#39;: &#39;general&#39;,
#       &#39;reasonName&#39;: &#39;globalInteractionReason&#39;}]},
#    &#39;venue&#39;: {&#39;id&#39;: &#39;53bbb8b3498ee6aee54c9216&#39;,
#     &#39;name&#39;: &#39;Restaurante Bacira&#39;,
#     &#39;contact&#39;: {},
#     &#39;location&#39;: {&#39;address&#39;: &#39;Castillo, 16&#39;,
#      &#39;crossStreet&#39;: &#39;Sagunto&#39;,
#      &#39;lat&#39;: 40.433803250381146,
#      &#39;lng&#39;: -3.6990506779000705,
#      &#39;labeledLatLngs&#39;: [{&#39;label&#39;: &#39;display&#39;,
#        &#39;lat&#39;: 40.433803250381146,
#        &#39;lng&#39;: -3.6990506779000705}],
#      &#39;distance&#39;: 1240,
#      &#39;postalCode&#39;: &#39;28010&#39;,
#      &#39;cc&#39;: &#39;ES&#39;,
#      &#39;neighborhood&#39;: &#39;Chamberí&#39;,
#      &#39;city&#39;: &#39;Madrid&#39;,
#      &#39;state&#39;: &#39;Madrid&#39;,
#      &#39;country&#39;: &#39;España&#39;,
#      &#39;formattedAddress&#39;: [&#39;Castillo, 16 (Sagunto)&#39;,
#       &#39;28010 Madrid Madrid&#39;,
#       &#39;España&#39;]},
#     &#39;categories&#39;: [{&#39;id&#39;: &#39;4bf58dd8d48988d1c4941735&#39;,
#       &#39;name&#39;: &#39;Restaurant&#39;,
#       &#39;pluralName&#39;: &#39;Restaurants&#39;,
#       &#39;shortName&#39;: &#39;Restaurant&#39;,
#       &#39;icon&#39;: {&#39;prefix&#39;: &#39;https://ss3.4sqi.net/img/categories_v2/food/default_&#39;,
#        &#39;suffix&#39;: &#39;.png&#39;},
#       &#39;primary&#39;: True}],
#     &#39;verified&#39;: False,
#     &#39;stats&#39;: {&#39;tipCount&#39;: 0,
#      &#39;usersCount&#39;: 0,
#      &#39;checkinsCount&#39;: 0,
#      &#39;visitsCount&#39;: 0},
#     &#39;beenHere&#39;: {&#39;count&#39;: 0,
#      &#39;lastCheckinExpiredAt&#39;: 0,
#      &#39;marked&#39;: False,
#      &#39;unconfirmedCount&#39;: 0},
#     &#39;photos&#39;: {&#39;count&#39;: 0, &#39;groups&#39;: []},
#     &#39;hereNow&#39;: {&#39;count&#39;: 0, &#39;summary&#39;: &#39;Nobody here&#39;, &#39;groups&#39;: []}},
#    &#39;referralId&#39;: &#39;e-3-53bbb8b3498ee6aee54c9216-87&#39;},
#   {&#39;reasons&#39;: {&#39;count&#39;: 0,
#     &#39;items&#39;: [{&#39;summary&#39;: &#39;This spot is popular&#39;,
#       &#39;type&#39;: &#39;general&#39;,
#       &#39;reasonName&#39;: &#39;globalInteractionReason&#39;}]},
#    &#39;venue&#39;: {&#39;id&#39;: &#39;4be2b9691dd22d7fb69e94bd&#39;,
#     &#39;name&#39;: &#39;La Sanabresa&#39;,
#     &#39;contact&#39;: {},
#     &#39;location&#39;: {&#39;address&#39;: &#39;C. Amor de Dios, 4&#39;,
#      &#39;lat&#39;: 40.41256047164362,
#      &#39;lng&#39;: -3.6984811188512157,
#      &#39;labeledLatLngs&#39;: [{&#39;label&#39;: &#39;display&#39;,
#        &#39;lat&#39;: 40.41256047164362,
#        &#39;lng&#39;: -3.6984811188512157}],
#      &#39;distance&#39;: 1132,
#      &#39;postalCode&#39;: &#39;28014&#39;,
#      &#39;cc&#39;: &#39;ES&#39;,
#      &#39;city&#39;: &#39;Madrid&#39;,
#      &#39;state&#39;: &#39;Madrid&#39;,
#      &#39;country&#39;: &#39;España&#39;,
#      &#39;formattedAddress&#39;: [&#39;C. Amor de Dios, 4&#39;,
#       &#39;28014 Madrid Madrid&#39;,
#       &#39;España&#39;]},
#     &#39;categories&#39;: [{&#39;id&#39;: &#39;4bf58dd8d48988d1c0941735&#39;,
#       &#39;name&#39;: &#39;Mediterranean Restaurant&#39;,
#       &#39;pluralName&#39;: &#39;Mediterranean Restaurants&#39;,
#       &#39;shortName&#39;: &#39;Mediterranean&#39;,
#       &#39;icon&#39;: {&#39;prefix&#39;: &#39;https://ss3.4sqi.net/img/categories_v2/food/mediterranean_&#39;,
#        &#39;suffix&#39;: &#39;.png&#39;},
#       &#39;primary&#39;: True}],
#     &#39;verified&#39;: False,
#     &#39;stats&#39;: {&#39;tipCount&#39;: 0,
#      &#39;usersCount&#39;: 0,
#      &#39;checkinsCount&#39;: 0,
#      &#39;visitsCount&#39;: 0},
#     &#39;beenHere&#39;: {&#39;count&#39;: 0,
#      &#39;lastCheckinExpiredAt&#39;: 0,
#      &#39;marked&#39;: False,
#      &#39;unconfirmedCount&#39;: 0},
#     &#39;photos&#39;: {&#39;count&#39;: 0, &#39;groups&#39;: []},
#     &#39;hereNow&#39;: {&#39;count&#39;: 0, &#39;summary&#39;: &#39;Nobody here&#39;, &#39;groups&#39;: []}},
#    &#39;referralId&#39;: &#39;e-3-4be2b9691dd22d7fb69e94bd-88&#39;},
#   {&#39;reasons&#39;: {&#39;count&#39;: 0,
#     &#39;items&#39;: [{&#39;summary&#39;: &#39;This spot is popular&#39;,
#       &#39;type&#39;: &#39;general&#39;,
#       &#39;reasonName&#39;: &#39;globalInteractionReason&#39;}]},
#    &#39;venue&#39;: {&#39;id&#39;: &#39;4b2cd572f964a520b0c924e3&#39;,
#     &#39;name&#39;: &#39;El Mollete&#39;,
#     &#39;contact&#39;: {},
#     &#39;location&#39;: {&#39;address&#39;: &#39;C. La Bola, 4&#39;,
#      &#39;lat&#39;: 40.419912891328146,
#      &#39;lng&#39;: -3.710502973556587,
#      &#39;labeledLatLngs&#39;: [{&#39;label&#39;: &#39;display&#39;,
#        &#39;lat&#39;: 40.419912891328146,
#        &#39;lng&#39;: -3.710502973556587}],
#      &#39;distance&#39;: 1136,
#      &#39;postalCode&#39;: &#39;28013&#39;,
#      &#39;cc&#39;: &#39;ES&#39;,
#      &#39;city&#39;: &#39;Madrid&#39;,
#      &#39;state&#39;: &#39;Madrid&#39;,
#      &#39;country&#39;: &#39;España&#39;,
#      &#39;formattedAddress&#39;: [&#39;C. La Bola, 4&#39;, &#39;28013 Madrid Madrid&#39;, &#39;España&#39;]},
#     &#39;categories&#39;: [{&#39;id&#39;: &#39;4bf58dd8d48988d1db931735&#39;,
#       &#39;name&#39;: &#39;Tapas Restaurant&#39;,
#       &#39;pluralName&#39;: &#39;Tapas Restaurants&#39;,
#       &#39;shortName&#39;: &#39;Tapas&#39;,
#       &#39;icon&#39;: {&#39;prefix&#39;: &#39;https://ss3.4sqi.net/img/categories_v2/food/tapas_&#39;,
#        &#39;suffix&#39;: &#39;.png&#39;},
#       &#39;primary&#39;: True}],
#     &#39;verified&#39;: False,
#     &#39;stats&#39;: {&#39;tipCount&#39;: 0,
#      &#39;usersCount&#39;: 0,
#      &#39;checkinsCount&#39;: 0,
#      &#39;visitsCount&#39;: 0},
#     &#39;beenHere&#39;: {&#39;count&#39;: 0,
#      &#39;lastCheckinExpiredAt&#39;: 0,
#      &#39;marked&#39;: False,
#      &#39;unconfirmedCount&#39;: 0},
#     &#39;photos&#39;: {&#39;count&#39;: 0, &#39;groups&#39;: []},
#     &#39;hereNow&#39;: {&#39;count&#39;: 0, &#39;summary&#39;: &#39;Nobody here&#39;, &#39;groups&#39;: []}},
#    &#39;referralId&#39;: &#39;e-3-4b2cd572f964a520b0c924e3-89&#39;},
#   {&#39;reasons&#39;: {&#39;count&#39;: 0,
#     &#39;items&#39;: [{&#39;summary&#39;: &#39;This spot is popular&#39;,
#       &#39;type&#39;: &#39;general&#39;,
#       &#39;reasonName&#39;: &#39;globalInteractionReason&#39;}]},
#    &#39;venue&#39;: {&#39;id&#39;: &#39;531dac8a498e60048308cff3&#39;,
#     &#39;name&#39;: &#39;GramaBar&#39;,
#     &#39;contact&#39;: {},
#     &#39;location&#39;: {&#39;address&#39;: &#39;C. Preciados, 40&#39;,
#      &#39;lat&#39;: 40.41976873108436,
#      &#39;lng&#39;: -3.7071476250900037,
#      &#39;labeledLatLngs&#39;: [{&#39;label&#39;: &#39;display&#39;,
#        &#39;lat&#39;: 40.41976873108436,
#        &#39;lng&#39;: -3.7071476250900037}],
#      &#39;distance&#39;: 872,
#      &#39;postalCode&#39;: &#39;28013&#39;,
#      &#39;cc&#39;: &#39;ES&#39;,
#      &#39;city&#39;: &#39;Madrid&#39;,
#      &#39;state&#39;: &#39;Madrid&#39;,
#      &#39;country&#39;: &#39;España&#39;,
#      &#39;formattedAddress&#39;: [&#39;C. Preciados, 40&#39;,
#       &#39;28013 Madrid Madrid&#39;,
#       &#39;España&#39;]},
#     &#39;categories&#39;: [{&#39;id&#39;: &#39;4bf58dd8d48988d155941735&#39;,
#       &#39;name&#39;: &#39;Gastropub&#39;,
#       &#39;pluralName&#39;: &#39;Gastropubs&#39;,
#       &#39;shortName&#39;: &#39;Gastropub&#39;,
#       &#39;icon&#39;: {&#39;prefix&#39;: &#39;https://ss3.4sqi.net/img/categories_v2/food/gastropub_&#39;,
#        &#39;suffix&#39;: &#39;.png&#39;},
#       &#39;primary&#39;: True}],
#     &#39;verified&#39;: True,
#     &#39;stats&#39;: {&#39;tipCount&#39;: 0,
#      &#39;usersCount&#39;: 0,
#      &#39;checkinsCount&#39;: 0,
#      &#39;visitsCount&#39;: 0},
#     &#39;beenHere&#39;: {&#39;count&#39;: 0,
#      &#39;lastCheckinExpiredAt&#39;: 0,
#      &#39;marked&#39;: False,
#      &#39;unconfirmedCount&#39;: 0},
#     &#39;photos&#39;: {&#39;count&#39;: 0, &#39;groups&#39;: []},
#     &#39;venuePage&#39;: {&#39;id&#39;: &#39;89411054&#39;},
#     &#39;hereNow&#39;: {&#39;count&#39;: 0, &#39;summary&#39;: &#39;Nobody here&#39;, &#39;groups&#39;: []}},
#    &#39;referralId&#39;: &#39;e-3-531dac8a498e60048308cff3-90&#39;},
#   {&#39;reasons&#39;: {&#39;count&#39;: 0,
#     &#39;items&#39;: [{&#39;summary&#39;: &#39;This spot is popular&#39;,
#       &#39;type&#39;: &#39;general&#39;,
#       &#39;reasonName&#39;: &#39;globalInteractionReason&#39;}]},
#    &#39;venue&#39;: {&#39;id&#39;: &#39;4c98adf707916dcb52faed1b&#39;,
#     &#39;name&#39;: &#39;La Tragantúa&#39;,
#     &#39;contact&#39;: {},
#     &#39;location&#39;: {&#39;address&#39;: &#39;C. Verónica, 4&#39;,
#      &#39;crossStreet&#39;: &#39;C. Fúcar&#39;,
#      &#39;lat&#39;: 40.41184555400155,
#      &#39;lng&#39;: -3.6954076239854836,
#      &#39;labeledLatLngs&#39;: [{&#39;label&#39;: &#39;display&#39;,
#        &#39;lat&#39;: 40.41184555400155,
#        &#39;lng&#39;: -3.6954076239854836}],
#      &#39;distance&#39;: 1224,
#      &#39;postalCode&#39;: &#39;28014&#39;,
#      &#39;cc&#39;: &#39;ES&#39;,
#      &#39;city&#39;: &#39;Madrid&#39;,
#      &#39;state&#39;: &#39;Madrid&#39;,
#      &#39;country&#39;: &#39;España&#39;,
#      &#39;formattedAddress&#39;: [&#39;C. Verónica, 4 (C. Fúcar)&#39;,
#       &#39;28014 Madrid Madrid&#39;,
#       &#39;España&#39;]},
#     &#39;categories&#39;: [{&#39;id&#39;: &#39;4bf58dd8d48988d150941735&#39;,
#       &#39;name&#39;: &#39;Spanish Restaurant&#39;,
#       &#39;pluralName&#39;: &#39;Spanish Restaurants&#39;,
#       &#39;shortName&#39;: &#39;Spanish&#39;,
#       &#39;icon&#39;: {&#39;prefix&#39;: &#39;https://ss3.4sqi.net/img/categories_v2/food/spanish_&#39;,
#        &#39;suffix&#39;: &#39;.png&#39;},
#       &#39;primary&#39;: True}],
#     &#39;verified&#39;: False,
#     &#39;stats&#39;: {&#39;tipCount&#39;: 0,
#      &#39;usersCount&#39;: 0,
#      &#39;checkinsCount&#39;: 0,
#      &#39;visitsCount&#39;: 0},
#     &#39;beenHere&#39;: {&#39;count&#39;: 0,
#      &#39;lastCheckinExpiredAt&#39;: 0,
#      &#39;marked&#39;: False,
#      &#39;unconfirmedCount&#39;: 0},
#     &#39;photos&#39;: {&#39;count&#39;: 0, &#39;groups&#39;: []},
#     &#39;hereNow&#39;: {&#39;count&#39;: 0, &#39;summary&#39;: &#39;Nobody here&#39;, &#39;groups&#39;: []}},
#    &#39;referralId&#39;: &#39;e-3-4c98adf707916dcb52faed1b-91&#39;},
#   {&#39;reasons&#39;: {&#39;count&#39;: 0,
#     &#39;items&#39;: [{&#39;summary&#39;: &#39;This spot is popular&#39;,
#       &#39;type&#39;: &#39;general&#39;,
#       &#39;reasonName&#39;: &#39;globalInteractionReason&#39;}]},
#    &#39;venue&#39;: {&#39;id&#39;: &#39;5a6db4f141868670dbfe3e89&#39;,
#     &#39;name&#39;: &#39;Delish Vegan Doughnuts&#39;,
#     &#39;contact&#39;: {},
#     &#39;location&#39;: {&#39;address&#39;: &#39;3 Calle del Cristo&#39;,
#      &#39;lat&#39;: 40.42694912512703,
#      &#39;lng&#39;: -3.7100989203246573,
#      &#39;labeledLatLngs&#39;: [{&#39;label&#39;: &#39;display&#39;,
#        &#39;lat&#39;: 40.42694912512703,
#        &#39;lng&#39;: -3.7100989203246573}],
#      &#39;distance&#39;: 1158,
#      &#39;postalCode&#39;: &#39;28015&#39;,
#      &#39;cc&#39;: &#39;ES&#39;,
#      &#39;neighborhood&#39;: &#39;Universidad&#39;,
#      &#39;city&#39;: &#39;Madrid&#39;,
#      &#39;state&#39;: &#39;Madrid&#39;,
#      &#39;country&#39;: &#39;España&#39;,
#      &#39;formattedAddress&#39;: [&#39;3 Calle del Cristo&#39;,
#       &#39;28015 Madrid Madrid&#39;,
#       &#39;España&#39;]},
#     &#39;categories&#39;: [{&#39;id&#39;: &#39;4bf58dd8d48988d148941735&#39;,
#       &#39;name&#39;: &#39;Donut Shop&#39;,
#       &#39;pluralName&#39;: &#39;Donut Shops&#39;,
#       &#39;shortName&#39;: &#39;Donuts&#39;,
#       &#39;icon&#39;: {&#39;prefix&#39;: &#39;https://ss3.4sqi.net/img/categories_v2/food/donuts_&#39;,
#        &#39;suffix&#39;: &#39;.png&#39;},
#       &#39;primary&#39;: True}],
#     &#39;verified&#39;: False,
#     &#39;stats&#39;: {&#39;tipCount&#39;: 0,
#      &#39;usersCount&#39;: 0,
#      &#39;checkinsCount&#39;: 0,
#      &#39;visitsCount&#39;: 0},
#     &#39;beenHere&#39;: {&#39;count&#39;: 0,
#      &#39;lastCheckinExpiredAt&#39;: 0,
#      &#39;marked&#39;: False,
#      &#39;unconfirmedCount&#39;: 0},
#     &#39;photos&#39;: {&#39;count&#39;: 0, &#39;groups&#39;: []},
#     &#39;hereNow&#39;: {&#39;count&#39;: 0, &#39;summary&#39;: &#39;Nobody here&#39;, &#39;groups&#39;: []}},
#    &#39;referralId&#39;: &#39;e-3-5a6db4f141868670dbfe3e89-92&#39;},
#   {&#39;reasons&#39;: {&#39;count&#39;: 0,
#     &#39;items&#39;: [{&#39;summary&#39;: &#39;This spot is popular&#39;,
#       &#39;type&#39;: &#39;general&#39;,
#       &#39;reasonName&#39;: &#39;globalInteractionReason&#39;}]},
#    &#39;venue&#39;: {&#39;id&#39;: &#39;54b51437498e8924f2766f00&#39;,
#     &#39;name&#39;: &#39;Salón Cascabel&#39;,
#     &#39;contact&#39;: {},
#     &#39;location&#39;: {&#39;address&#39;: &#39;Serrano 52, 7 planta&#39;,
#      &#39;crossStreet&#39;: &#39;Ayala&#39;,
#      &#39;lat&#39;: 40.427699920608354,
#      &#39;lng&#39;: -3.6872659298342922,
#      &#39;labeledLatLngs&#39;: [{&#39;label&#39;: &#39;display&#39;,
#        &#39;lat&#39;: 40.427699920608354,
#        &#39;lng&#39;: -3.6872659298342922}],
#      &#39;distance&#39;: 1037,
#      &#39;postalCode&#39;: &#39;28001&#39;,
#      &#39;cc&#39;: &#39;ES&#39;,
#      &#39;city&#39;: &#39;Madrid Centro, Madrid&#39;,
#      &#39;state&#39;: &#39;Madrid&#39;,
#      &#39;country&#39;: &#39;España&#39;,
#      &#39;formattedAddress&#39;: [&#39;Serrano 52, 7 planta (Ayala)&#39;,
#       &#39;28001 Madrid Centro Madrid&#39;,
#       &#39;España&#39;]},
#     &#39;categories&#39;: [{&#39;id&#39;: &#39;4bf58dd8d48988d1c1941735&#39;,
#       &#39;name&#39;: &#39;Mexican Restaurant&#39;,
#       &#39;pluralName&#39;: &#39;Mexican Restaurants&#39;,
#       &#39;shortName&#39;: &#39;Mexican&#39;,
#       &#39;icon&#39;: {&#39;prefix&#39;: &#39;https://ss3.4sqi.net/img/categories_v2/food/mexican_&#39;,
#        &#39;suffix&#39;: &#39;.png&#39;},
#       &#39;primary&#39;: True}],
#     &#39;verified&#39;: False,
#     &#39;stats&#39;: {&#39;tipCount&#39;: 0,
#      &#39;usersCount&#39;: 0,
#      &#39;checkinsCount&#39;: 0,
#      &#39;visitsCount&#39;: 0},
#     &#39;beenHere&#39;: {&#39;count&#39;: 0,
#      &#39;lastCheckinExpiredAt&#39;: 0,
#      &#39;marked&#39;: False,
#      &#39;unconfirmedCount&#39;: 0},
#     &#39;photos&#39;: {&#39;count&#39;: 0, &#39;groups&#39;: []},
#     &#39;hereNow&#39;: {&#39;count&#39;: 0, &#39;summary&#39;: &#39;Nobody here&#39;, &#39;groups&#39;: []}},
#    &#39;referralId&#39;: &#39;e-3-54b51437498e8924f2766f00-93&#39;},
#   {&#39;reasons&#39;: {&#39;count&#39;: 0,
#     &#39;items&#39;: [{&#39;summary&#39;: &#39;This spot is popular&#39;,
#       &#39;type&#39;: &#39;general&#39;,
#       &#39;reasonName&#39;: &#39;globalInteractionReason&#39;}]},
#    &#39;venue&#39;: {&#39;id&#39;: &#39;5a2454e3fd16bb353b4ec264&#39;,
#     &#39;name&#39;: &#39;La Esperanza&#39;,
#     &#39;contact&#39;: {},
#     &#39;location&#39;: {&#39;address&#39;: &#39;C. Torrecilla del Leal, 3&#39;,
#      &#39;lat&#39;: 40.41149716350271,
#      &#39;lng&#39;: -3.6994495684985402,
#      &#39;labeledLatLngs&#39;: [{&#39;label&#39;: &#39;display&#39;,
#        &#39;lat&#39;: 40.41149716350271,
#        &#39;lng&#39;: -3.6994495684985402}],
#      &#39;distance&#39;: 1258,
#      &#39;postalCode&#39;: &#39;28012&#39;,
#      &#39;cc&#39;: &#39;ES&#39;,
#      &#39;city&#39;: &#39;Madrid&#39;,
#      &#39;state&#39;: &#39;Madrid&#39;,
#      &#39;country&#39;: &#39;España&#39;,
#      &#39;formattedAddress&#39;: [&#39;C. Torrecilla del Leal, 3&#39;,
#       &#39;28012 Madrid Madrid&#39;,
#       &#39;España&#39;]},
#     &#39;categories&#39;: [{&#39;id&#39;: &#39;4bf58dd8d48988d1c0941735&#39;,
#       &#39;name&#39;: &#39;Mediterranean Restaurant&#39;,
#       &#39;pluralName&#39;: &#39;Mediterranean Restaurants&#39;,
#       &#39;shortName&#39;: &#39;Mediterranean&#39;,
#       &#39;icon&#39;: {&#39;prefix&#39;: &#39;https://ss3.4sqi.net/img/categories_v2/food/mediterranean_&#39;,
#        &#39;suffix&#39;: &#39;.png&#39;},
#       &#39;primary&#39;: True}],
#     &#39;verified&#39;: False,
#     &#39;stats&#39;: {&#39;tipCount&#39;: 0,
#      &#39;usersCount&#39;: 0,
#      &#39;checkinsCount&#39;: 0,
#      &#39;visitsCount&#39;: 0},
#     &#39;beenHere&#39;: {&#39;count&#39;: 0,
#      &#39;lastCheckinExpiredAt&#39;: 0,
#      &#39;marked&#39;: False,
#      &#39;unconfirmedCount&#39;: 0},
#     &#39;photos&#39;: {&#39;count&#39;: 0, &#39;groups&#39;: []},
#     &#39;hereNow&#39;: {&#39;count&#39;: 0, &#39;summary&#39;: &#39;Nobody here&#39;, &#39;groups&#39;: []}},
#    &#39;referralId&#39;: &#39;e-3-5a2454e3fd16bb353b4ec264-94&#39;},
#   {&#39;reasons&#39;: {&#39;count&#39;: 0,
#     &#39;items&#39;: [{&#39;summary&#39;: &#39;This spot is popular&#39;,
#       &#39;type&#39;: &#39;general&#39;,
#       &#39;reasonName&#39;: &#39;globalInteractionReason&#39;}]},
#    &#39;venue&#39;: {&#39;id&#39;: &#39;4b7bf438f964a52096752fe3&#39;,
#     &#39;name&#39;: &#39;El Senador&#39;,
#     &#39;contact&#39;: {},
#     &#39;location&#39;: {&#39;address&#39;: &#39;Plaza de La Marina Española, 2&#39;,
#      &#39;lat&#39;: 40.42076966674159,
#      &#39;lng&#39;: -3.7114585151950705,
#      &#39;labeledLatLngs&#39;: [{&#39;label&#39;: &#39;display&#39;,
#        &#39;lat&#39;: 40.42076966674159,
#        &#39;lng&#39;: -3.7114585151950705}],
#      &#39;distance&#39;: 1193,
#      &#39;postalCode&#39;: &#39;28013&#39;,
#      &#39;cc&#39;: &#39;ES&#39;,
#      &#39;city&#39;: &#39;Madrid&#39;,
#      &#39;state&#39;: &#39;Madrid&#39;,
#      &#39;country&#39;: &#39;España&#39;,
#      &#39;formattedAddress&#39;: [&#39;Plaza de La Marina Española, 2&#39;,
#       &#39;28013 Madrid Madrid&#39;,
#       &#39;España&#39;]},
#     &#39;categories&#39;: [{&#39;id&#39;: &#39;4bf58dd8d48988d150941735&#39;,
#       &#39;name&#39;: &#39;Spanish Restaurant&#39;,
#       &#39;pluralName&#39;: &#39;Spanish Restaurants&#39;,
#       &#39;shortName&#39;: &#39;Spanish&#39;,
#       &#39;icon&#39;: {&#39;prefix&#39;: &#39;https://ss3.4sqi.net/img/categories_v2/food/spanish_&#39;,
#        &#39;suffix&#39;: &#39;.png&#39;},
#       &#39;primary&#39;: True}],
#     &#39;verified&#39;: False,
#     &#39;stats&#39;: {&#39;tipCount&#39;: 0,
#      &#39;usersCount&#39;: 0,
#      &#39;checkinsCount&#39;: 0,
#      &#39;visitsCount&#39;: 0},
#     &#39;beenHere&#39;: {&#39;count&#39;: 0,
#      &#39;lastCheckinExpiredAt&#39;: 0,
#      &#39;marked&#39;: False,
#      &#39;unconfirmedCount&#39;: 0},
#     &#39;photos&#39;: {&#39;count&#39;: 0, &#39;groups&#39;: []},
#     &#39;hereNow&#39;: {&#39;count&#39;: 0, &#39;summary&#39;: &#39;Nobody here&#39;, &#39;groups&#39;: []}},
#    &#39;referralId&#39;: &#39;e-3-4b7bf438f964a52096752fe3-95&#39;},
#   {&#39;reasons&#39;: {&#39;count&#39;: 0,
#     &#39;items&#39;: [{&#39;summary&#39;: &#39;This spot is popular&#39;,
#       &#39;type&#39;: &#39;general&#39;,
#       &#39;reasonName&#39;: &#39;globalInteractionReason&#39;}]},
#    &#39;venue&#39;: {&#39;id&#39;: &#39;4bbf8bbaf8219c74752ab010&#39;,
#     &#39;name&#39;: &#39;El Sur&#39;,
#     &#39;contact&#39;: {},
#     &#39;location&#39;: {&#39;address&#39;: &#39;C. Torrecilla del Leal, 12&#39;,
#      &#39;lat&#39;: 40.411135324189495,
#      &#39;lng&#39;: -3.699521331741858,
#      &#39;labeledLatLngs&#39;: [{&#39;label&#39;: &#39;display&#39;,
#        &#39;lat&#39;: 40.411135324189495,
#        &#39;lng&#39;: -3.699521331741858}],
#      &#39;distance&#39;: 1298,
#      &#39;postalCode&#39;: &#39;28012&#39;,
#      &#39;cc&#39;: &#39;ES&#39;,
#      &#39;city&#39;: &#39;Madrid&#39;,
#      &#39;state&#39;: &#39;Madrid&#39;,
#      &#39;country&#39;: &#39;España&#39;,
#      &#39;formattedAddress&#39;: [&#39;C. Torrecilla del Leal, 12&#39;,
#       &#39;28012 Madrid Madrid&#39;,
#       &#39;España&#39;]},
#     &#39;categories&#39;: [{&#39;id&#39;: &#39;4bf58dd8d48988d1c4941735&#39;,
#       &#39;name&#39;: &#39;Restaurant&#39;,
#       &#39;pluralName&#39;: &#39;Restaurants&#39;,
#       &#39;shortName&#39;: &#39;Restaurant&#39;,
#       &#39;icon&#39;: {&#39;prefix&#39;: &#39;https://ss3.4sqi.net/img/categories_v2/food/default_&#39;,
#        &#39;suffix&#39;: &#39;.png&#39;},
#       &#39;primary&#39;: True}],
#     &#39;verified&#39;: False,
#     &#39;stats&#39;: {&#39;tipCount&#39;: 0,
#      &#39;usersCount&#39;: 0,
#      &#39;checkinsCount&#39;: 0,
#      &#39;visitsCount&#39;: 0},
#     &#39;beenHere&#39;: {&#39;count&#39;: 0,
#      &#39;lastCheckinExpiredAt&#39;: 0,
#      &#39;marked&#39;: False,
#      &#39;unconfirmedCount&#39;: 0},
#     &#39;photos&#39;: {&#39;count&#39;: 0, &#39;groups&#39;: []},
#     &#39;hereNow&#39;: {&#39;count&#39;: 0, &#39;summary&#39;: &#39;Nobody here&#39;, &#39;groups&#39;: []}},
#    &#39;referralId&#39;: &#39;e-3-4bbf8bbaf8219c74752ab010-96&#39;},
#   {&#39;reasons&#39;: {&#39;count&#39;: 0,
#     &#39;items&#39;: [{&#39;summary&#39;: &#39;This spot is popular&#39;,
#       &#39;type&#39;: &#39;general&#39;,
#       &#39;reasonName&#39;: &#39;globalInteractionReason&#39;}]},
#    &#39;venue&#39;: {&#39;id&#39;: &#39;52d96b74498e34079b6bbf2a&#39;,
#     &#39;name&#39;: &#39;MORE&#39;,
#     &#39;contact&#39;: {},
#     &#39;location&#39;: {&#39;address&#39;: &#39;Jorge Juan,25&#39;,
#      &#39;crossStreet&#39;: &#39;Velázquez&#39;,
#      &#39;lat&#39;: 40.42388443976496,
#      &#39;lng&#39;: -3.6838091221418963,
#      &#39;labeledLatLngs&#39;: [{&#39;label&#39;: &#39;display&#39;,
#        &#39;lat&#39;: 40.42388443976496,
#        &#39;lng&#39;: -3.6838091221418963}],
#      &#39;distance&#39;: 1176,
#      &#39;postalCode&#39;: &#39;28001&#39;,
#      &#39;cc&#39;: &#39;ES&#39;,
#      &#39;city&#39;: &#39;Madrid&#39;,
#      &#39;state&#39;: &#39;Madrid&#39;,
#      &#39;country&#39;: &#39;España&#39;,
#      &#39;formattedAddress&#39;: [&#39;Jorge Juan,25 (Velázquez)&#39;,
#       &#39;28001 Madrid Madrid&#39;,
#       &#39;España&#39;]},
#     &#39;categories&#39;: [{&#39;id&#39;: &#39;4bf58dd8d48988d1c4941735&#39;,
#       &#39;name&#39;: &#39;Restaurant&#39;,
#       &#39;pluralName&#39;: &#39;Restaurants&#39;,
#       &#39;shortName&#39;: &#39;Restaurant&#39;,
#       &#39;icon&#39;: {&#39;prefix&#39;: &#39;https://ss3.4sqi.net/img/categories_v2/food/default_&#39;,
#        &#39;suffix&#39;: &#39;.png&#39;},
#       &#39;primary&#39;: True}],
#     &#39;verified&#39;: False,
#     &#39;stats&#39;: {&#39;tipCount&#39;: 0,
#      &#39;usersCount&#39;: 0,
#      &#39;checkinsCount&#39;: 0,
#      &#39;visitsCount&#39;: 0},
#     &#39;beenHere&#39;: {&#39;count&#39;: 0,
#      &#39;lastCheckinExpiredAt&#39;: 0,
#      &#39;marked&#39;: False,
#      &#39;unconfirmedCount&#39;: 0},
#     &#39;photos&#39;: {&#39;count&#39;: 0, &#39;groups&#39;: []},
#     &#39;hereNow&#39;: {&#39;count&#39;: 0, &#39;summary&#39;: &#39;Nobody here&#39;, &#39;groups&#39;: []}},
#    &#39;referralId&#39;: &#39;e-3-52d96b74498e34079b6bbf2a-97&#39;},
#   {&#39;reasons&#39;: {&#39;count&#39;: 0,
#     &#39;items&#39;: [{&#39;summary&#39;: &#39;This spot is popular&#39;,
#       &#39;type&#39;: &#39;general&#39;,
#       &#39;reasonName&#39;: &#39;globalInteractionReason&#39;}]},
#    &#39;venue&#39;: {&#39;id&#39;: &#39;51335848e4b0cfae58777e98&#39;,
#     &#39;name&#39;: &#39;El Cielo&#39;,
#     &#39;contact&#39;: {},
#     &#39;location&#39;: {&#39;address&#39;: &#39;Calle Fúcar, 4&#39;,
#      &#39;lat&#39;: 40.4124737354003,
#      &#39;lng&#39;: -3.6956884720810095,
#      &#39;labeledLatLngs&#39;: [{&#39;label&#39;: &#39;display&#39;,
#        &#39;lat&#39;: 40.4124737354003,
#        &#39;lng&#39;: -3.6956884720810095}],
#      &#39;distance&#39;: 1151,
#      &#39;postalCode&#39;: &#39;28014&#39;,
#      &#39;cc&#39;: &#39;ES&#39;,
#      &#39;city&#39;: &#39;Madrid&#39;,
#      &#39;state&#39;: &#39;Madrid&#39;,
#      &#39;country&#39;: &#39;España&#39;,
#      &#39;formattedAddress&#39;: [&#39;Calle Fúcar, 4&#39;, &#39;28014 Madrid Madrid&#39;, &#39;España&#39;]},
#     &#39;categories&#39;: [{&#39;id&#39;: &#39;4bf58dd8d48988d1cb941735&#39;,
#       &#39;name&#39;: &#39;Food Truck&#39;,
#       &#39;pluralName&#39;: &#39;Food Trucks&#39;,
#       &#39;shortName&#39;: &#39;Food Truck&#39;,
#       &#39;icon&#39;: {&#39;prefix&#39;: &#39;https://ss3.4sqi.net/img/categories_v2/food/streetfood_&#39;,
#        &#39;suffix&#39;: &#39;.png&#39;},
#       &#39;primary&#39;: True}],
#     &#39;verified&#39;: False,
#     &#39;stats&#39;: {&#39;tipCount&#39;: 0,
#      &#39;usersCount&#39;: 0,
#      &#39;checkinsCount&#39;: 0,
#      &#39;visitsCount&#39;: 0},
#     &#39;beenHere&#39;: {&#39;count&#39;: 0,
#      &#39;lastCheckinExpiredAt&#39;: 0,
#      &#39;marked&#39;: False,
#      &#39;unconfirmedCount&#39;: 0},
#     &#39;photos&#39;: {&#39;count&#39;: 0, &#39;groups&#39;: []},
#     &#39;hereNow&#39;: {&#39;count&#39;: 0, &#39;summary&#39;: &#39;Nobody here&#39;, &#39;groups&#39;: []}},
#    &#39;referralId&#39;: &#39;e-3-51335848e4b0cfae58777e98-98&#39;},
#   {&#39;reasons&#39;: {&#39;count&#39;: 0,
#     &#39;items&#39;: [{&#39;summary&#39;: &#39;This spot is popular&#39;,
#       &#39;type&#39;: &#39;general&#39;,
#       &#39;reasonName&#39;: &#39;globalInteractionReason&#39;}]},
#    &#39;venue&#39;: {&#39;id&#39;: &#39;525ad2cc498e875d748818fd&#39;,
#     &#39;name&#39;: &#39;Federal Café&#39;,
#     &#39;contact&#39;: {},
#     &#39;location&#39;: {&#39;address&#39;: &#39;Pl. de las Comendadoras, 9&#39;,
#      &#39;crossStreet&#39;: &#39;C. Amaniel, 30&#39;,
#      &#39;lat&#39;: 40.427173427148695,
#      &#39;lng&#39;: -3.7092873110522837,
#      &#39;labeledLatLngs&#39;: [{&#39;label&#39;: &#39;display&#39;,
#        &#39;lat&#39;: 40.427173427148695,
#        &#39;lng&#39;: -3.7092873110522837}],
#      &#39;distance&#39;: 1107,
#      &#39;postalCode&#39;: &#39;28015&#39;,
#      &#39;cc&#39;: &#39;ES&#39;,
#      &#39;city&#39;: &#39;Madrid&#39;,
#      &#39;state&#39;: &#39;Madrid&#39;,
#      &#39;country&#39;: &#39;España&#39;,
#      &#39;formattedAddress&#39;: [&#39;Pl. de las Comendadoras, 9 (C. Amaniel, 30)&#39;,
#       &#39;28015 Madrid Madrid&#39;,
#       &#39;España&#39;]},
#     &#39;categories&#39;: [{&#39;id&#39;: &#39;4bf58dd8d48988d16d941735&#39;,
#       &#39;name&#39;: &#39;Café&#39;,
#       &#39;pluralName&#39;: &#39;Cafés&#39;,
#       &#39;shortName&#39;: &#39;Café&#39;,
#       &#39;icon&#39;: {&#39;prefix&#39;: &#39;https://ss3.4sqi.net/img/categories_v2/food/cafe_&#39;,
#        &#39;suffix&#39;: &#39;.png&#39;},
#       &#39;primary&#39;: True}],
#     &#39;verified&#39;: False,
#     &#39;stats&#39;: {&#39;tipCount&#39;: 0,
#      &#39;usersCount&#39;: 0,
#      &#39;checkinsCount&#39;: 0,
#      &#39;visitsCount&#39;: 0},
#     &#39;beenHere&#39;: {&#39;count&#39;: 0,
#      &#39;lastCheckinExpiredAt&#39;: 0,
#      &#39;marked&#39;: False,
#      &#39;unconfirmedCount&#39;: 0},
#     &#39;photos&#39;: {&#39;count&#39;: 0, &#39;groups&#39;: []},
#     &#39;hereNow&#39;: {&#39;count&#39;: 0, &#39;summary&#39;: &#39;Nobody here&#39;, &#39;groups&#39;: []}},
#    &#39;referralId&#39;: &#39;e-3-525ad2cc498e875d748818fd-99&#39;}]}

# %%
data["response"]['groups'][0].keys()
# Out:
# dict_keys([&#39;type&#39;, &#39;name&#39;, &#39;items&#39;])

# %%
data["response"]['groups'][0]['items']
# Out:
# f58dd8d48988d1d2941735&#39;,
#      &#39;name&#39;: &#39;Sushi Restaurant&#39;,
#      &#39;pluralName&#39;: &#39;Sushi Restaurants&#39;,
#      &#39;shortName&#39;: &#39;Sushi&#39;,
#      &#39;icon&#39;: {&#39;prefix&#39;: &#39;https://ss3.4sqi.net/img/categories_v2/food/sushi_&#39;,
#       &#39;suffix&#39;: &#39;.png&#39;},
#      &#39;primary&#39;: True}],
#    &#39;verified&#39;: False,
#    &#39;stats&#39;: {&#39;tipCount&#39;: 0,
#     &#39;usersCount&#39;: 0,
#     &#39;checkinsCount&#39;: 0,
#     &#39;visitsCount&#39;: 0},
#    &#39;beenHere&#39;: {&#39;count&#39;: 0,
#     &#39;lastCheckinExpiredAt&#39;: 0,
#     &#39;marked&#39;: False,
#     &#39;unconfirmedCount&#39;: 0},
#    &#39;photos&#39;: {&#39;count&#39;: 0, &#39;groups&#39;: []},
#    &#39;hereNow&#39;: {&#39;count&#39;: 0, &#39;summary&#39;: &#39;Nobody here&#39;, &#39;groups&#39;: []}},
#   &#39;referralId&#39;: &#39;e-3-4f2d2e4ae4b0124ab827520d-85&#39;},
#  {&#39;reasons&#39;: {&#39;count&#39;: 0,
#    &#39;items&#39;: [{&#39;summary&#39;: &#39;This spot is popular&#39;,
#      &#39;type&#39;: &#39;general&#39;,
#      &#39;reasonName&#39;: &#39;globalInteractionReason&#39;}]},
#   &#39;venue&#39;: {&#39;id&#39;: &#39;538ce5df498eb2165bface85&#39;,
#    &#39;name&#39;: &#39;Yakitoro&#39;,
#    &#39;contact&#39;: {},
#    &#39;location&#39;: {&#39;address&#39;: &#39;C. de la Reina, 41&#39;,
#     &#39;lat&#39;: 40.419647701387746,
#     &#39;lng&#39;: -3.697201837743589,
#     &#39;labeledLatLngs&#39;: [{&#39;label&#39;: &#39;display&#39;,
#       &#39;lat&#39;: 40.419647701387746,
#       &#39;lng&#39;: -3.697201837743589}],
#     &#39;distance&#39;: 342,
#     &#39;postalCode&#39;: &#39;28001&#39;,
#     &#39;cc&#39;: &#39;ES&#39;,
#     &#39;city&#39;: &#39;Madrid&#39;,
#     &#39;state&#39;: &#39;Madrid&#39;,
#     &#39;country&#39;: &#39;España&#39;,
#     &#39;formattedAddress&#39;: [&#39;C. de la Reina, 41&#39;,
#      &#39;28001 Madrid Madrid&#39;,
#      &#39;España&#39;]},
#    &#39;categories&#39;: [{&#39;id&#39;: &#39;4bf58dd8d48988d111941735&#39;,
#      &#39;name&#39;: &#39;Japanese Restaurant&#39;,
#      &#39;pluralName&#39;: &#39;Japanese Restaurants&#39;,
#      &#39;shortName&#39;: &#39;Japanese&#39;,
#      &#39;icon&#39;: {&#39;prefix&#39;: &#39;https://ss3.4sqi.net/img/categories_v2/food/japanese_&#39;,
#       &#39;suffix&#39;: &#39;.png&#39;},
#      &#39;primary&#39;: True}],
#    &#39;verified&#39;: False,
#    &#39;stats&#39;: {&#39;tipCount&#39;: 0,
#     &#39;usersCount&#39;: 0,
#     &#39;checkinsCount&#39;: 0,
#     &#39;visitsCount&#39;: 0},
#    &#39;beenHere&#39;: {&#39;count&#39;: 0,
#     &#39;lastCheckinExpiredAt&#39;: 0,
#     &#39;marked&#39;: False,
#     &#39;unconfirmedCount&#39;: 0},
#    &#39;photos&#39;: {&#39;count&#39;: 0, &#39;groups&#39;: []},
#    &#39;hereNow&#39;: {&#39;count&#39;: 0, &#39;summary&#39;: &#39;Nobody here&#39;, &#39;groups&#39;: []}},
#   &#39;referralId&#39;: &#39;e-3-538ce5df498eb2165bface85-86&#39;},
#  {&#39;reasons&#39;: {&#39;count&#39;: 0,
#    &#39;items&#39;: [{&#39;summary&#39;: &#39;This spot is popular&#39;,
#      &#39;type&#39;: &#39;general&#39;,
#      &#39;reasonName&#39;: &#39;globalInteractionReason&#39;}]},
#   &#39;venue&#39;: {&#39;id&#39;: &#39;53bbb8b3498ee6aee54c9216&#39;,
#    &#39;name&#39;: &#39;Restaurante Bacira&#39;,
#    &#39;contact&#39;: {},
#    &#39;location&#39;: {&#39;address&#39;: &#39;Castillo, 16&#39;,
#     &#39;crossStreet&#39;: &#39;Sagunto&#39;,
#     &#39;lat&#39;: 40.433803250381146,
#     &#39;lng&#39;: -3.6990506779000705,
#     &#39;labeledLatLngs&#39;: [{&#39;label&#39;: &#39;display&#39;,
#       &#39;lat&#39;: 40.433803250381146,
#       &#39;lng&#39;: -3.6990506779000705}],
#     &#39;distance&#39;: 1240,
#     &#39;postalCode&#39;: &#39;28010&#39;,
#     &#39;cc&#39;: &#39;ES&#39;,
#     &#39;neighborhood&#39;: &#39;Chamberí&#39;,
#     &#39;city&#39;: &#39;Madrid&#39;,
#     &#39;state&#39;: &#39;Madrid&#39;,
#     &#39;country&#39;: &#39;España&#39;,
#     &#39;formattedAddress&#39;: [&#39;Castillo, 16 (Sagunto)&#39;,
#      &#39;28010 Madrid Madrid&#39;,
#      &#39;España&#39;]},
#    &#39;categories&#39;: [{&#39;id&#39;: &#39;4bf58dd8d48988d1c4941735&#39;,
#      &#39;name&#39;: &#39;Restaurant&#39;,
#      &#39;pluralName&#39;: &#39;Restaurants&#39;,
#      &#39;shortName&#39;: &#39;Restaurant&#39;,
#      &#39;icon&#39;: {&#39;prefix&#39;: &#39;https://ss3.4sqi.net/img/categories_v2/food/default_&#39;,
#       &#39;suffix&#39;: &#39;.png&#39;},
#      &#39;primary&#39;: True}],
#    &#39;verified&#39;: False,
#    &#39;stats&#39;: {&#39;tipCount&#39;: 0,
#     &#39;usersCount&#39;: 0,
#     &#39;checkinsCount&#39;: 0,
#     &#39;visitsCount&#39;: 0},
#    &#39;beenHere&#39;: {&#39;count&#39;: 0,
#     &#39;lastCheckinExpiredAt&#39;: 0,
#     &#39;marked&#39;: False,
#     &#39;unconfirmedCount&#39;: 0},
#    &#39;photos&#39;: {&#39;count&#39;: 0, &#39;groups&#39;: []},
#    &#39;hereNow&#39;: {&#39;count&#39;: 0, &#39;summary&#39;: &#39;Nobody here&#39;, &#39;groups&#39;: []}},
#   &#39;referralId&#39;: &#39;e-3-53bbb8b3498ee6aee54c9216-87&#39;},
#  {&#39;reasons&#39;: {&#39;count&#39;: 0,
#    &#39;items&#39;: [{&#39;summary&#39;: &#39;This spot is popular&#39;,
#      &#39;type&#39;: &#39;general&#39;,
#      &#39;reasonName&#39;: &#39;globalInteractionReason&#39;}]},
#   &#39;venue&#39;: {&#39;id&#39;: &#39;4be2b9691dd22d7fb69e94bd&#39;,
#    &#39;name&#39;: &#39;La Sanabresa&#39;,
#    &#39;contact&#39;: {},
#    &#39;location&#39;: {&#39;address&#39;: &#39;C. Amor de Dios, 4&#39;,
#     &#39;lat&#39;: 40.41256047164362,
#     &#39;lng&#39;: -3.6984811188512157,
#     &#39;labeledLatLngs&#39;: [{&#39;label&#39;: &#39;display&#39;,
#       &#39;lat&#39;: 40.41256047164362,
#       &#39;lng&#39;: -3.6984811188512157}],
#     &#39;distance&#39;: 1132,
#     &#39;postalCode&#39;: &#39;28014&#39;,
#     &#39;cc&#39;: &#39;ES&#39;,
#     &#39;city&#39;: &#39;Madrid&#39;,
#     &#39;state&#39;: &#39;Madrid&#39;,
#     &#39;country&#39;: &#39;España&#39;,
#     &#39;formattedAddress&#39;: [&#39;C. Amor de Dios, 4&#39;,
#      &#39;28014 Madrid Madrid&#39;,
#      &#39;España&#39;]},
#    &#39;categories&#39;: [{&#39;id&#39;: &#39;4bf58dd8d48988d1c0941735&#39;,
#      &#39;name&#39;: &#39;Mediterranean Restaurant&#39;,
#      &#39;pluralName&#39;: &#39;Mediterranean Restaurants&#39;,
#      &#39;shortName&#39;: &#39;Mediterranean&#39;,
#      &#39;icon&#39;: {&#39;prefix&#39;: &#39;https://ss3.4sqi.net/img/categories_v2/food/mediterranean_&#39;,
#       &#39;suffix&#39;: &#39;.png&#39;},
#      &#39;primary&#39;: True}],
#    &#39;verified&#39;: False,
#    &#39;stats&#39;: {&#39;tipCount&#39;: 0,
#     &#39;usersCount&#39;: 0,
#     &#39;checkinsCount&#39;: 0,
#     &#39;visitsCount&#39;: 0},
#    &#39;beenHere&#39;: {&#39;count&#39;: 0,
#     &#39;lastCheckinExpiredAt&#39;: 0,
#     &#39;marked&#39;: False,
#     &#39;unconfirmedCount&#39;: 0},
#    &#39;photos&#39;: {&#39;count&#39;: 0, &#39;groups&#39;: []},
#    &#39;hereNow&#39;: {&#39;count&#39;: 0, &#39;summary&#39;: &#39;Nobody here&#39;, &#39;groups&#39;: []}},
#   &#39;referralId&#39;: &#39;e-3-4be2b9691dd22d7fb69e94bd-88&#39;},
#  {&#39;reasons&#39;: {&#39;count&#39;: 0,
#    &#39;items&#39;: [{&#39;summary&#39;: &#39;This spot is popular&#39;,
#      &#39;type&#39;: &#39;general&#39;,
#      &#39;reasonName&#39;: &#39;globalInteractionReason&#39;}]},
#   &#39;venue&#39;: {&#39;id&#39;: &#39;4b2cd572f964a520b0c924e3&#39;,
#    &#39;name&#39;: &#39;El Mollete&#39;,
#    &#39;contact&#39;: {},
#    &#39;location&#39;: {&#39;address&#39;: &#39;C. La Bola, 4&#39;,
#     &#39;lat&#39;: 40.419912891328146,
#     &#39;lng&#39;: -3.710502973556587,
#     &#39;labeledLatLngs&#39;: [{&#39;label&#39;: &#39;display&#39;,
#       &#39;lat&#39;: 40.419912891328146,
#       &#39;lng&#39;: -3.710502973556587}],
#     &#39;distance&#39;: 1136,
#     &#39;postalCode&#39;: &#39;28013&#39;,
#     &#39;cc&#39;: &#39;ES&#39;,
#     &#39;city&#39;: &#39;Madrid&#39;,
#     &#39;state&#39;: &#39;Madrid&#39;,
#     &#39;country&#39;: &#39;España&#39;,
#     &#39;formattedAddress&#39;: [&#39;C. La Bola, 4&#39;, &#39;28013 Madrid Madrid&#39;, &#39;España&#39;]},
#    &#39;categories&#39;: [{&#39;id&#39;: &#39;4bf58dd8d48988d1db931735&#39;,
#      &#39;name&#39;: &#39;Tapas Restaurant&#39;,
#      &#39;pluralName&#39;: &#39;Tapas Restaurants&#39;,
#      &#39;shortName&#39;: &#39;Tapas&#39;,
#      &#39;icon&#39;: {&#39;prefix&#39;: &#39;https://ss3.4sqi.net/img/categories_v2/food/tapas_&#39;,
#       &#39;suffix&#39;: &#39;.png&#39;},
#      &#39;primary&#39;: True}],
#    &#39;verified&#39;: False,
#    &#39;stats&#39;: {&#39;tipCount&#39;: 0,
#     &#39;usersCount&#39;: 0,
#     &#39;checkinsCount&#39;: 0,
#     &#39;visitsCount&#39;: 0},
#    &#39;beenHere&#39;: {&#39;count&#39;: 0,
#     &#39;lastCheckinExpiredAt&#39;: 0,
#     &#39;marked&#39;: False,
#     &#39;unconfirmedCount&#39;: 0},
#    &#39;photos&#39;: {&#39;count&#39;: 0, &#39;groups&#39;: []},
#    &#39;hereNow&#39;: {&#39;count&#39;: 0, &#39;summary&#39;: &#39;Nobody here&#39;, &#39;groups&#39;: []}},
#   &#39;referralId&#39;: &#39;e-3-4b2cd572f964a520b0c924e3-89&#39;},
#  {&#39;reasons&#39;: {&#39;count&#39;: 0,
#    &#39;items&#39;: [{&#39;summary&#39;: &#39;This spot is popular&#39;,
#      &#39;type&#39;: &#39;general&#39;,
#      &#39;reasonName&#39;: &#39;globalInteractionReason&#39;}]},
#   &#39;venue&#39;: {&#39;id&#39;: &#39;531dac8a498e60048308cff3&#39;,
#    &#39;name&#39;: &#39;GramaBar&#39;,
#    &#39;contact&#39;: {},
#    &#39;location&#39;: {&#39;address&#39;: &#39;C. Preciados, 40&#39;,
#     &#39;lat&#39;: 40.41976873108436,
#     &#39;lng&#39;: -3.7071476250900037,
#     &#39;labeledLatLngs&#39;: [{&#39;label&#39;: &#39;display&#39;,
#       &#39;lat&#39;: 40.41976873108436,
#       &#39;lng&#39;: -3.7071476250900037}],
#     &#39;distance&#39;: 872,
#     &#39;postalCode&#39;: &#39;28013&#39;,
#     &#39;cc&#39;: &#39;ES&#39;,
#     &#39;city&#39;: &#39;Madrid&#39;,
#     &#39;state&#39;: &#39;Madrid&#39;,
#     &#39;country&#39;: &#39;España&#39;,
#     &#39;formattedAddress&#39;: [&#39;C. Preciados, 40&#39;, &#39;28013 Madrid Madrid&#39;, &#39;España&#39;]},
#    &#39;categories&#39;: [{&#39;id&#39;: &#39;4bf58dd8d48988d155941735&#39;,
#      &#39;name&#39;: &#39;Gastropub&#39;,
#      &#39;pluralName&#39;: &#39;Gastropubs&#39;,
#      &#39;shortName&#39;: &#39;Gastropub&#39;,
#      &#39;icon&#39;: {&#39;prefix&#39;: &#39;https://ss3.4sqi.net/img/categories_v2/food/gastropub_&#39;,
#       &#39;suffix&#39;: &#39;.png&#39;},
#      &#39;primary&#39;: True}],
#    &#39;verified&#39;: True,
#    &#39;stats&#39;: {&#39;tipCount&#39;: 0,
#     &#39;usersCount&#39;: 0,
#     &#39;checkinsCount&#39;: 0,
#     &#39;visitsCount&#39;: 0},
#    &#39;beenHere&#39;: {&#39;count&#39;: 0,
#     &#39;lastCheckinExpiredAt&#39;: 0,
#     &#39;marked&#39;: False,
#     &#39;unconfirmedCount&#39;: 0},
#    &#39;photos&#39;: {&#39;count&#39;: 0, &#39;groups&#39;: []},
#    &#39;venuePage&#39;: {&#39;id&#39;: &#39;89411054&#39;},
#    &#39;hereNow&#39;: {&#39;count&#39;: 0, &#39;summary&#39;: &#39;Nobody here&#39;, &#39;groups&#39;: []}},
#   &#39;referralId&#39;: &#39;e-3-531dac8a498e60048308cff3-90&#39;},
#  {&#39;reasons&#39;: {&#39;count&#39;: 0,
#    &#39;items&#39;: [{&#39;summary&#39;: &#39;This spot is popular&#39;,
#      &#39;type&#39;: &#39;general&#39;,
#      &#39;reasonName&#39;: &#39;globalInteractionReason&#39;}]},
#   &#39;venue&#39;: {&#39;id&#39;: &#39;4c98adf707916dcb52faed1b&#39;,
#    &#39;name&#39;: &#39;La Tragantúa&#39;,
#    &#39;contact&#39;: {},
#    &#39;location&#39;: {&#39;address&#39;: &#39;C. Verónica, 4&#39;,
#     &#39;crossStreet&#39;: &#39;C. Fúcar&#39;,
#     &#39;lat&#39;: 40.41184555400155,
#     &#39;lng&#39;: -3.6954076239854836,
#     &#39;labeledLatLngs&#39;: [{&#39;label&#39;: &#39;display&#39;,
#       &#39;lat&#39;: 40.41184555400155,
#       &#39;lng&#39;: -3.6954076239854836}],
#     &#39;distance&#39;: 1224,
#     &#39;postalCode&#39;: &#39;28014&#39;,
#     &#39;cc&#39;: &#39;ES&#39;,
#     &#39;city&#39;: &#39;Madrid&#39;,
#     &#39;state&#39;: &#39;Madrid&#39;,
#     &#39;country&#39;: &#39;España&#39;,
#     &#39;formattedAddress&#39;: [&#39;C. Verónica, 4 (C. Fúcar)&#39;,
#      &#39;28014 Madrid Madrid&#39;,
#      &#39;España&#39;]},
#    &#39;categories&#39;: [{&#39;id&#39;: &#39;4bf58dd8d48988d150941735&#39;,
#      &#39;name&#39;: &#39;Spanish Restaurant&#39;,
#      &#39;pluralName&#39;: &#39;Spanish Restaurants&#39;,
#      &#39;shortName&#39;: &#39;Spanish&#39;,
#      &#39;icon&#39;: {&#39;prefix&#39;: &#39;https://ss3.4sqi.net/img/categories_v2/food/spanish_&#39;,
#       &#39;suffix&#39;: &#39;.png&#39;},
#      &#39;primary&#39;: True}],
#    &#39;verified&#39;: False,
#    &#39;stats&#39;: {&#39;tipCount&#39;: 0,
#     &#39;usersCount&#39;: 0,
#     &#39;checkinsCount&#39;: 0,
#     &#39;visitsCount&#39;: 0},
#    &#39;beenHere&#39;: {&#39;count&#39;: 0,
#     &#39;lastCheckinExpiredAt&#39;: 0,
#     &#39;marked&#39;: False,
#     &#39;unconfirmedCount&#39;: 0},
#    &#39;photos&#39;: {&#39;count&#39;: 0, &#39;groups&#39;: []},
#    &#39;hereNow&#39;: {&#39;count&#39;: 0, &#39;summary&#39;: &#39;Nobody here&#39;, &#39;groups&#39;: []}},
#   &#39;referralId&#39;: &#39;e-3-4c98adf707916dcb52faed1b-91&#39;},
#  {&#39;reasons&#39;: {&#39;count&#39;: 0,
#    &#39;items&#39;: [{&#39;summary&#39;: &#39;This spot is popular&#39;,
#      &#39;type&#39;: &#39;general&#39;,
#      &#39;reasonName&#39;: &#39;globalInteractionReason&#39;}]},
#   &#39;venue&#39;: {&#39;id&#39;: &#39;5a6db4f141868670dbfe3e89&#39;,
#    &#39;name&#39;: &#39;Delish Vegan Doughnuts&#39;,
#    &#39;contact&#39;: {},
#    &#39;location&#39;: {&#39;address&#39;: &#39;3 Calle del Cristo&#39;,
#     &#39;lat&#39;: 40.42694912512703,
#     &#39;lng&#39;: -3.7100989203246573,
#     &#39;labeledLatLngs&#39;: [{&#39;label&#39;: &#39;display&#39;,
#       &#39;lat&#39;: 40.42694912512703,
#       &#39;lng&#39;: -3.7100989203246573}],
#     &#39;distance&#39;: 1158,
#     &#39;postalCode&#39;: &#39;28015&#39;,
#     &#39;cc&#39;: &#39;ES&#39;,
#     &#39;neighborhood&#39;: &#39;Universidad&#39;,
#     &#39;city&#39;: &#39;Madrid&#39;,
#     &#39;state&#39;: &#39;Madrid&#39;,
#     &#39;country&#39;: &#39;España&#39;,
#     &#39;formattedAddress&#39;: [&#39;3 Calle del Cristo&#39;,
#      &#39;28015 Madrid Madrid&#39;,
#      &#39;España&#39;]},
#    &#39;categories&#39;: [{&#39;id&#39;: &#39;4bf58dd8d48988d148941735&#39;,
#      &#39;name&#39;: &#39;Donut Shop&#39;,
#      &#39;pluralName&#39;: &#39;Donut Shops&#39;,
#      &#39;shortName&#39;: &#39;Donuts&#39;,
#      &#39;icon&#39;: {&#39;prefix&#39;: &#39;https://ss3.4sqi.net/img/categories_v2/food/donuts_&#39;,
#       &#39;suffix&#39;: &#39;.png&#39;},
#      &#39;primary&#39;: True}],
#    &#39;verified&#39;: False,
#    &#39;stats&#39;: {&#39;tipCount&#39;: 0,
#     &#39;usersCount&#39;: 0,
#     &#39;checkinsCount&#39;: 0,
#     &#39;visitsCount&#39;: 0},
#    &#39;beenHere&#39;: {&#39;count&#39;: 0,
#     &#39;lastCheckinExpiredAt&#39;: 0,
#     &#39;marked&#39;: False,
#     &#39;unconfirmedCount&#39;: 0},
#    &#39;photos&#39;: {&#39;count&#39;: 0, &#39;groups&#39;: []},
#    &#39;hereNow&#39;: {&#39;count&#39;: 0, &#39;summary&#39;: &#39;Nobody here&#39;, &#39;groups&#39;: []}},
#   &#39;referralId&#39;: &#39;e-3-5a6db4f141868670dbfe3e89-92&#39;},
#  {&#39;reasons&#39;: {&#39;count&#39;: 0,
#    &#39;items&#39;: [{&#39;summary&#39;: &#39;This spot is popular&#39;,
#      &#39;type&#39;: &#39;general&#39;,
#      &#39;reasonName&#39;: &#39;globalInteractionReason&#39;}]},
#   &#39;venue&#39;: {&#39;id&#39;: &#39;54b51437498e8924f2766f00&#39;,
#    &#39;name&#39;: &#39;Salón Cascabel&#39;,
#    &#39;contact&#39;: {},
#    &#39;location&#39;: {&#39;address&#39;: &#39;Serrano 52, 7 planta&#39;,
#     &#39;crossStreet&#39;: &#39;Ayala&#39;,
#     &#39;lat&#39;: 40.427699920608354,
#     &#39;lng&#39;: -3.6872659298342922,
#     &#39;labeledLatLngs&#39;: [{&#39;label&#39;: &#39;display&#39;,
#       &#39;lat&#39;: 40.427699920608354,
#       &#39;lng&#39;: -3.6872659298342922}],
#     &#39;distance&#39;: 1037,
#     &#39;postalCode&#39;: &#39;28001&#39;,
#     &#39;cc&#39;: &#39;ES&#39;,
#     &#39;city&#39;: &#39;Madrid Centro, Madrid&#39;,
#     &#39;state&#39;: &#39;Madrid&#39;,
#     &#39;country&#39;: &#39;España&#39;,
#     &#39;formattedAddress&#39;: [&#39;Serrano 52, 7 planta (Ayala)&#39;,
#      &#39;28001 Madrid Centro Madrid&#39;,
#      &#39;España&#39;]},
#    &#39;categories&#39;: [{&#39;id&#39;: &#39;4bf58dd8d48988d1c1941735&#39;,
#      &#39;name&#39;: &#39;Mexican Restaurant&#39;,
#      &#39;pluralName&#39;: &#39;Mexican Restaurants&#39;,
#      &#39;shortName&#39;: &#39;Mexican&#39;,
#      &#39;icon&#39;: {&#39;prefix&#39;: &#39;https://ss3.4sqi.net/img/categories_v2/food/mexican_&#39;,
#       &#39;suffix&#39;: &#39;.png&#39;},
#      &#39;primary&#39;: True}],
#    &#39;verified&#39;: False,
#    &#39;stats&#39;: {&#39;tipCount&#39;: 0,
#     &#39;usersCount&#39;: 0,
#     &#39;checkinsCount&#39;: 0,
#     &#39;visitsCount&#39;: 0},
#    &#39;beenHere&#39;: {&#39;count&#39;: 0,
#     &#39;lastCheckinExpiredAt&#39;: 0,
#     &#39;marked&#39;: False,
#     &#39;unconfirmedCount&#39;: 0},
#    &#39;photos&#39;: {&#39;count&#39;: 0, &#39;groups&#39;: []},
#    &#39;hereNow&#39;: {&#39;count&#39;: 0, &#39;summary&#39;: &#39;Nobody here&#39;, &#39;groups&#39;: []}},
#   &#39;referralId&#39;: &#39;e-3-54b51437498e8924f2766f00-93&#39;},
#  {&#39;reasons&#39;: {&#39;count&#39;: 0,
#    &#39;items&#39;: [{&#39;summary&#39;: &#39;This spot is popular&#39;,
#      &#39;type&#39;: &#39;general&#39;,
#      &#39;reasonName&#39;: &#39;globalInteractionReason&#39;}]},
#   &#39;venue&#39;: {&#39;id&#39;: &#39;5a2454e3fd16bb353b4ec264&#39;,
#    &#39;name&#39;: &#39;La Esperanza&#39;,
#    &#39;contact&#39;: {},
#    &#39;location&#39;: {&#39;address&#39;: &#39;C. Torrecilla del Leal, 3&#39;,
#     &#39;lat&#39;: 40.41149716350271,
#     &#39;lng&#39;: -3.6994495684985402,
#     &#39;labeledLatLngs&#39;: [{&#39;label&#39;: &#39;display&#39;,
#       &#39;lat&#39;: 40.41149716350271,
#       &#39;lng&#39;: -3.6994495684985402}],
#     &#39;distance&#39;: 1258,
#     &#39;postalCode&#39;: &#39;28012&#39;,
#     &#39;cc&#39;: &#39;ES&#39;,
#     &#39;city&#39;: &#39;Madrid&#39;,
#     &#39;state&#39;: &#39;Madrid&#39;,
#     &#39;country&#39;: &#39;España&#39;,
#     &#39;formattedAddress&#39;: [&#39;C. Torrecilla del Leal, 3&#39;,
#      &#39;28012 Madrid Madrid&#39;,
#      &#39;España&#39;]},
#    &#39;categories&#39;: [{&#39;id&#39;: &#39;4bf58dd8d48988d1c0941735&#39;,
#      &#39;name&#39;: &#39;Mediterranean Restaurant&#39;,
#      &#39;pluralName&#39;: &#39;Mediterranean Restaurants&#39;,
#      &#39;shortName&#39;: &#39;Mediterranean&#39;,
#      &#39;icon&#39;: {&#39;prefix&#39;: &#39;https://ss3.4sqi.net/img/categories_v2/food/mediterranean_&#39;,
#       &#39;suffix&#39;: &#39;.png&#39;},
#      &#39;primary&#39;: True}],
#    &#39;verified&#39;: False,
#    &#39;stats&#39;: {&#39;tipCount&#39;: 0,
#     &#39;usersCount&#39;: 0,
#     &#39;checkinsCount&#39;: 0,
#     &#39;visitsCount&#39;: 0},
#    &#39;beenHere&#39;: {&#39;count&#39;: 0,
#     &#39;lastCheckinExpiredAt&#39;: 0,
#     &#39;marked&#39;: False,
#     &#39;unconfirmedCount&#39;: 0},
#    &#39;photos&#39;: {&#39;count&#39;: 0, &#39;groups&#39;: []},
#    &#39;hereNow&#39;: {&#39;count&#39;: 0, &#39;summary&#39;: &#39;Nobody here&#39;, &#39;groups&#39;: []}},
#   &#39;referralId&#39;: &#39;e-3-5a2454e3fd16bb353b4ec264-94&#39;},
#  {&#39;reasons&#39;: {&#39;count&#39;: 0,
#    &#39;items&#39;: [{&#39;summary&#39;: &#39;This spot is popular&#39;,
#      &#39;type&#39;: &#39;general&#39;,
#      &#39;reasonName&#39;: &#39;globalInteractionReason&#39;}]},
#   &#39;venue&#39;: {&#39;id&#39;: &#39;4b7bf438f964a52096752fe3&#39;,
#    &#39;name&#39;: &#39;El Senador&#39;,
#    &#39;contact&#39;: {},
#    &#39;location&#39;: {&#39;address&#39;: &#39;Plaza de La Marina Española, 2&#39;,
#     &#39;lat&#39;: 40.42076966674159,
#     &#39;lng&#39;: -3.7114585151950705,
#     &#39;labeledLatLngs&#39;: [{&#39;label&#39;: &#39;display&#39;,
#       &#39;lat&#39;: 40.42076966674159,
#       &#39;lng&#39;: -3.7114585151950705}],
#     &#39;distance&#39;: 1193,
#     &#39;postalCode&#39;: &#39;28013&#39;,
#     &#39;cc&#39;: &#39;ES&#39;,
#     &#39;city&#39;: &#39;Madrid&#39;,
#     &#39;state&#39;: &#39;Madrid&#39;,
#     &#39;country&#39;: &#39;España&#39;,
#     &#39;formattedAddress&#39;: [&#39;Plaza de La Marina Española, 2&#39;,
#      &#39;28013 Madrid Madrid&#39;,
#      &#39;España&#39;]},
#    &#39;categories&#39;: [{&#39;id&#39;: &#39;4bf58dd8d48988d150941735&#39;,
#      &#39;name&#39;: &#39;Spanish Restaurant&#39;,
#      &#39;pluralName&#39;: &#39;Spanish Restaurants&#39;,
#      &#39;shortName&#39;: &#39;Spanish&#39;,
#      &#39;icon&#39;: {&#39;prefix&#39;: &#39;https://ss3.4sqi.net/img/categories_v2/food/spanish_&#39;,
#       &#39;suffix&#39;: &#39;.png&#39;},
#      &#39;primary&#39;: True}],
#    &#39;verified&#39;: False,
#    &#39;stats&#39;: {&#39;tipCount&#39;: 0,
#     &#39;usersCount&#39;: 0,
#     &#39;checkinsCount&#39;: 0,
#     &#39;visitsCount&#39;: 0},
#    &#39;beenHere&#39;: {&#39;count&#39;: 0,
#     &#39;lastCheckinExpiredAt&#39;: 0,
#     &#39;marked&#39;: False,
#     &#39;unconfirmedCount&#39;: 0},
#    &#39;photos&#39;: {&#39;count&#39;: 0, &#39;groups&#39;: []},
#    &#39;hereNow&#39;: {&#39;count&#39;: 0, &#39;summary&#39;: &#39;Nobody here&#39;, &#39;groups&#39;: []}},
#   &#39;referralId&#39;: &#39;e-3-4b7bf438f964a52096752fe3-95&#39;},
#  {&#39;reasons&#39;: {&#39;count&#39;: 0,
#    &#39;items&#39;: [{&#39;summary&#39;: &#39;This spot is popular&#39;,
#      &#39;type&#39;: &#39;general&#39;,
#      &#39;reasonName&#39;: &#39;globalInteractionReason&#39;}]},
#   &#39;venue&#39;: {&#39;id&#39;: &#39;4bbf8bbaf8219c74752ab010&#39;,
#    &#39;name&#39;: &#39;El Sur&#39;,
#    &#39;contact&#39;: {},
#    &#39;location&#39;: {&#39;address&#39;: &#39;C. Torrecilla del Leal, 12&#39;,
#     &#39;lat&#39;: 40.411135324189495,
#     &#39;lng&#39;: -3.699521331741858,
#     &#39;labeledLatLngs&#39;: [{&#39;label&#39;: &#39;display&#39;,
#       &#39;lat&#39;: 40.411135324189495,
#       &#39;lng&#39;: -3.699521331741858}],
#     &#39;distance&#39;: 1298,
#     &#39;postalCode&#39;: &#39;28012&#39;,
#     &#39;cc&#39;: &#39;ES&#39;,
#     &#39;city&#39;: &#39;Madrid&#39;,
#     &#39;state&#39;: &#39;Madrid&#39;,
#     &#39;country&#39;: &#39;España&#39;,
#     &#39;formattedAddress&#39;: [&#39;C. Torrecilla del Leal, 12&#39;,
#      &#39;28012 Madrid Madrid&#39;,
#      &#39;España&#39;]},
#    &#39;categories&#39;: [{&#39;id&#39;: &#39;4bf58dd8d48988d1c4941735&#39;,
#      &#39;name&#39;: &#39;Restaurant&#39;,
#      &#39;pluralName&#39;: &#39;Restaurants&#39;,
#      &#39;shortName&#39;: &#39;Restaurant&#39;,
#      &#39;icon&#39;: {&#39;prefix&#39;: &#39;https://ss3.4sqi.net/img/categories_v2/food/default_&#39;,
#       &#39;suffix&#39;: &#39;.png&#39;},
#      &#39;primary&#39;: True}],
#    &#39;verified&#39;: False,
#    &#39;stats&#39;: {&#39;tipCount&#39;: 0,
#     &#39;usersCount&#39;: 0,
#     &#39;checkinsCount&#39;: 0,
#     &#39;visitsCount&#39;: 0},
#    &#39;beenHere&#39;: {&#39;count&#39;: 0,
#     &#39;lastCheckinExpiredAt&#39;: 0,
#     &#39;marked&#39;: False,
#     &#39;unconfirmedCount&#39;: 0},
#    &#39;photos&#39;: {&#39;count&#39;: 0, &#39;groups&#39;: []},
#    &#39;hereNow&#39;: {&#39;count&#39;: 0, &#39;summary&#39;: &#39;Nobody here&#39;, &#39;groups&#39;: []}},
#   &#39;referralId&#39;: &#39;e-3-4bbf8bbaf8219c74752ab010-96&#39;},
#  {&#39;reasons&#39;: {&#39;count&#39;: 0,
#    &#39;items&#39;: [{&#39;summary&#39;: &#39;This spot is popular&#39;,
#      &#39;type&#39;: &#39;general&#39;,
#      &#39;reasonName&#39;: &#39;globalInteractionReason&#39;}]},
#   &#39;venue&#39;: {&#39;id&#39;: &#39;52d96b74498e34079b6bbf2a&#39;,
#    &#39;name&#39;: &#39;MORE&#39;,
#    &#39;contact&#39;: {},
#    &#39;location&#39;: {&#39;address&#39;: &#39;Jorge Juan,25&#39;,
#     &#39;crossStreet&#39;: &#39;Velázquez&#39;,
#     &#39;lat&#39;: 40.42388443976496,
#     &#39;lng&#39;: -3.6838091221418963,
#     &#39;labeledLatLngs&#39;: [{&#39;label&#39;: &#39;display&#39;,
#       &#39;lat&#39;: 40.42388443976496,
#       &#39;lng&#39;: -3.6838091221418963}],
#     &#39;distance&#39;: 1176,
#     &#39;postalCode&#39;: &#39;28001&#39;,
#     &#39;cc&#39;: &#39;ES&#39;,
#     &#39;city&#39;: &#39;Madrid&#39;,
#     &#39;state&#39;: &#39;Madrid&#39;,
#     &#39;country&#39;: &#39;España&#39;,
#     &#39;formattedAddress&#39;: [&#39;Jorge Juan,25 (Velázquez)&#39;,
#      &#39;28001 Madrid Madrid&#39;,
#      &#39;España&#39;]},
#    &#39;categories&#39;: [{&#39;id&#39;: &#39;4bf58dd8d48988d1c4941735&#39;,
#      &#39;name&#39;: &#39;Restaurant&#39;,
#      &#39;pluralName&#39;: &#39;Restaurants&#39;,
#      &#39;shortName&#39;: &#39;Restaurant&#39;,
#      &#39;icon&#39;: {&#39;prefix&#39;: &#39;https://ss3.4sqi.net/img/categories_v2/food/default_&#39;,
#       &#39;suffix&#39;: &#39;.png&#39;},
#      &#39;primary&#39;: True}],
#    &#39;verified&#39;: False,
#    &#39;stats&#39;: {&#39;tipCount&#39;: 0,
#     &#39;usersCount&#39;: 0,
#     &#39;checkinsCount&#39;: 0,
#     &#39;visitsCount&#39;: 0},
#    &#39;beenHere&#39;: {&#39;count&#39;: 0,
#     &#39;lastCheckinExpiredAt&#39;: 0,
#     &#39;marked&#39;: False,
#     &#39;unconfirmedCount&#39;: 0},
#    &#39;photos&#39;: {&#39;count&#39;: 0, &#39;groups&#39;: []},
#    &#39;hereNow&#39;: {&#39;count&#39;: 0, &#39;summary&#39;: &#39;Nobody here&#39;, &#39;groups&#39;: []}},
#   &#39;referralId&#39;: &#39;e-3-52d96b74498e34079b6bbf2a-97&#39;},
#  {&#39;reasons&#39;: {&#39;count&#39;: 0,
#    &#39;items&#39;: [{&#39;summary&#39;: &#39;This spot is popular&#39;,
#      &#39;type&#39;: &#39;general&#39;,
#      &#39;reasonName&#39;: &#39;globalInteractionReason&#39;}]},
#   &#39;venue&#39;: {&#39;id&#39;: &#39;51335848e4b0cfae58777e98&#39;,
#    &#39;name&#39;: &#39;El Cielo&#39;,
#    &#39;contact&#39;: {},
#    &#39;location&#39;: {&#39;address&#39;: &#39;Calle Fúcar, 4&#39;,
#     &#39;lat&#39;: 40.4124737354003,
#     &#39;lng&#39;: -3.6956884720810095,
#     &#39;labeledLatLngs&#39;: [{&#39;label&#39;: &#39;display&#39;,
#       &#39;lat&#39;: 40.4124737354003,
#       &#39;lng&#39;: -3.6956884720810095}],
#     &#39;distance&#39;: 1151,
#     &#39;postalCode&#39;: &#39;28014&#39;,
#     &#39;cc&#39;: &#39;ES&#39;,
#     &#39;city&#39;: &#39;Madrid&#39;,
#     &#39;state&#39;: &#39;Madrid&#39;,
#     &#39;country&#39;: &#39;España&#39;,
#     &#39;formattedAddress&#39;: [&#39;Calle Fúcar, 4&#39;, &#39;28014 Madrid Madrid&#39;, &#39;España&#39;]},
#    &#39;categories&#39;: [{&#39;id&#39;: &#39;4bf58dd8d48988d1cb941735&#39;,
#      &#39;name&#39;: &#39;Food Truck&#39;,
#      &#39;pluralName&#39;: &#39;Food Trucks&#39;,
#      &#39;shortName&#39;: &#39;Food Truck&#39;,
#      &#39;icon&#39;: {&#39;prefix&#39;: &#39;https://ss3.4sqi.net/img/categories_v2/food/streetfood_&#39;,
#       &#39;suffix&#39;: &#39;.png&#39;},
#      &#39;primary&#39;: True}],
#    &#39;verified&#39;: False,
#    &#39;stats&#39;: {&#39;tipCount&#39;: 0,
#     &#39;usersCount&#39;: 0,
#     &#39;checkinsCount&#39;: 0,
#     &#39;visitsCount&#39;: 0},
#    &#39;beenHere&#39;: {&#39;count&#39;: 0,
#     &#39;lastCheckinExpiredAt&#39;: 0,
#     &#39;marked&#39;: False,
#     &#39;unconfirmedCount&#39;: 0},
#    &#39;photos&#39;: {&#39;count&#39;: 0, &#39;groups&#39;: []},
#    &#39;hereNow&#39;: {&#39;count&#39;: 0, &#39;summary&#39;: &#39;Nobody here&#39;, &#39;groups&#39;: []}},
#   &#39;referralId&#39;: &#39;e-3-51335848e4b0cfae58777e98-98&#39;},
#  {&#39;reasons&#39;: {&#39;count&#39;: 0,
#    &#39;items&#39;: [{&#39;summary&#39;: &#39;This spot is popular&#39;,
#      &#39;type&#39;: &#39;general&#39;,
#      &#39;reasonName&#39;: &#39;globalInteractionReason&#39;}]},
#   &#39;venue&#39;: {&#39;id&#39;: &#39;525ad2cc498e875d748818fd&#39;,
#    &#39;name&#39;: &#39;Federal Café&#39;,
#    &#39;contact&#39;: {},
#    &#39;location&#39;: {&#39;address&#39;: &#39;Pl. de las Comendadoras, 9&#39;,
#     &#39;crossStreet&#39;: &#39;C. Amaniel, 30&#39;,
#     &#39;lat&#39;: 40.427173427148695,
#     &#39;lng&#39;: -3.7092873110522837,
#     &#39;labeledLatLngs&#39;: [{&#39;label&#39;: &#39;display&#39;,
#       &#39;lat&#39;: 40.427173427148695,
#       &#39;lng&#39;: -3.7092873110522837}],
#     &#39;distance&#39;: 1107,
#     &#39;postalCode&#39;: &#39;28015&#39;,
#     &#39;cc&#39;: &#39;ES&#39;,
#     &#39;city&#39;: &#39;Madrid&#39;,
#     &#39;state&#39;: &#39;Madrid&#39;,
#     &#39;country&#39;: &#39;España&#39;,
#     &#39;formattedAddress&#39;: [&#39;Pl. de las Comendadoras, 9 (C. Amaniel, 30)&#39;,
#      &#39;28015 Madrid Madrid&#39;,
#      &#39;España&#39;]},
#    &#39;categories&#39;: [{&#39;id&#39;: &#39;4bf58dd8d48988d16d941735&#39;,
#      &#39;name&#39;: &#39;Café&#39;,
#      &#39;pluralName&#39;: &#39;Cafés&#39;,
#      &#39;shortName&#39;: &#39;Café&#39;,
#      &#39;icon&#39;: {&#39;prefix&#39;: &#39;https://ss3.4sqi.net/img/categories_v2/food/cafe_&#39;,
#       &#39;suffix&#39;: &#39;.png&#39;},
#      &#39;primary&#39;: True}],
#    &#39;verified&#39;: False,
#    &#39;stats&#39;: {&#39;tipCount&#39;: 0,
#     &#39;usersCount&#39;: 0,
#     &#39;checkinsCount&#39;: 0,
#     &#39;visitsCount&#39;: 0},
#    &#39;beenHere&#39;: {&#39;count&#39;: 0,
#     &#39;lastCheckinExpiredAt&#39;: 0,
#     &#39;marked&#39;: False,
#     &#39;unconfirmedCount&#39;: 0},
#    &#39;photos&#39;: {&#39;count&#39;: 0, &#39;groups&#39;: []},
#    &#39;hereNow&#39;: {&#39;count&#39;: 0, &#39;summary&#39;: &#39;Nobody here&#39;, &#39;groups&#39;: []}},
#   &#39;referralId&#39;: &#39;e-3-525ad2cc498e875d748818fd-99&#39;}]

# %%
data["response"]['groups'][0]['items'][0].keys()
# Out:
# dict_keys([&#39;reasons&#39;, &#39;venue&#39;, &#39;referralId&#39;])

# %%
data["response"]['groups'][0]['items'][0]['venue'].keys()
# Out:
# dict_keys([&#39;id&#39;, &#39;name&#39;, &#39;contact&#39;, &#39;location&#39;, &#39;categories&#39;, &#39;verified&#39;, &#39;stats&#39;, &#39;beenHere&#39;, &#39;photos&#39;, &#39;hereNow&#39;])

# %%
data["response"]['groups'][0]['items'][0]['venue']['name']
# Este es el camino para obtener el nombre del restaurante
# Out:
# &#39;Honest Greens&#39;

# %%
data["response"]['groups'][0]['items'][0]['venue']['location']
#De aqui podría obtener la direccion y las coordenadas
# Out:
# {&#39;address&#39;: &#39;Calle Hortaleza 100&#39;,
#  &#39;lat&#39;: 40.42487975679924,
#  &#39;lng&#39;: -3.697894121919185,
#  &#39;labeledLatLngs&#39;: [{&#39;label&#39;: &#39;display&#39;,
#    &#39;lat&#39;: 40.42487975679924,
#    &#39;lng&#39;: -3.697894121919185}],
#  &#39;distance&#39;: 242,
#  &#39;postalCode&#39;: &#39;28004&#39;,
#  &#39;cc&#39;: &#39;ES&#39;,
#  &#39;neighborhood&#39;: &#39;Chueca&#39;,
#  &#39;city&#39;: &#39;Madrid&#39;,
#  &#39;state&#39;: &#39;Madrid&#39;,
#  &#39;country&#39;: &#39;España&#39;,
#  &#39;formattedAddress&#39;: [&#39;Calle Hortaleza 100&#39;, &#39;28004 Madrid Madrid&#39;, &#39;España&#39;]}

# %%
data["response"]['groups'][0]['items'][0]['venue']['location'].keys()
# Out:
# dict_keys([&#39;address&#39;, &#39;lat&#39;, &#39;lng&#39;, &#39;labeledLatLngs&#39;, &#39;distance&#39;, &#39;postalCode&#39;, &#39;cc&#39;, &#39;neighborhood&#39;, &#39;city&#39;, &#39;state&#39;, &#39;country&#39;, &#39;formattedAddress&#39;])

# %%
data["response"]['groups'][0]['items'][0]['venue']['location']['address']
# El camino para obtener la dirección de cada restaurante
# Out:
# &#39;Calle Hortaleza 100&#39;

# %%
data["response"]['groups'][0]['items'][0]['venue']['location']['lat']
# Esta es la latitud
# Out:
# 40.42487975679924

# %%
data["response"]['groups'][0]['items'][0]['venue']['location']['lng']
# Out:
# -3.697894121919185

# %%
data["response"]['groups'][0]['items'][0]['venue']['location']['formattedAddress']
# Out:
# [&#39;Calle Hortaleza 100&#39;, &#39;28004 Madrid Madrid&#39;, &#39;España&#39;]

# %%
for rest in data["response"]['groups'][0]["items"]:
    print(rest["venue"]["name"])
# Out:
# Honest Greens
# La Hummuseria
# Kuoco 360
# DSTAgE
# celicioso
# Vides
# La Primera
# Panod
# Cannibal Raw Bar
# Charrua
# Angelita Madrid
# Hot Now
# El Cafetin De Fernando VI
# Krachai
# The Brunch Club
# La Pescadería
# Ôven Mozzarella Bar
# Capperi Mercato Italiano
# Casa Hortensia
# La Tavernetta
# Bosco de Lobos
# Doki Doki
# La Colmada
# ORIO Fuencarral
# Umiko
# Café de la Luz
# TAKOS
# Lamucca de Almagro
# Pelotari
# Pez Tortilla
# La Cabaña Argentina
# Lamucca
# Askua barra
# Ojalá
# Raimunda
# La Pulpería de Victoria
# El Jardín Secreto de SB
# Alabaster
# Habanera
# Cafe Angelica
# Pontepez
# El Inti de Oro
# Bacoa
# Aarde
# Mu! El placer de la carne
# Canalla Bistro by Ricard Camarena
# New York Burger
# VEGA
# Chilling Café
# 99 Sushi Bar
# Ten Con Ten
# Rosi La Loca
# InClan Brutal Bar
# El Paraguas
# tuk tuk
# Eat Is Wok
# Fellina
# La Fondue De Tell
# Casa Pueblo
# Carmencita
# Casa Federica
# StreetXO
# Amazónico
# Restaurante Lily
# Restaurante Viva Madrid
# La Maquina Jorge Juan
# Casa Labra
# Arrocería Marina Ventura
# Asador de Aranda
# Ferpal
# Casa Jaguar
# Musashi
# Casa Dani
# Tepic
# La Gringa
# Vinoteca Moratín
# Casa Lafu
# Ferreteria By Ego
# Trattoria Malatesta
# Plenti
# La Dichosa
# El Perro y La Galleta
# Platea Madrid
# Kabuki Wellington
# La Bien Aparecida
# Yoka Loka
# Yakitoro
# Restaurante Bacira
# La Sanabresa
# El Mollete
# GramaBar
# La Tragantúa
# Delish Vegan Doughnuts
# Salón Cascabel
# La Esperanza
# El Senador
# El Sur
# MORE
# El Cielo
# Federal Café

# %%
nombre = [elem1["venue"]["name"] for elem1 in data["response"]['groups'][0]["items"]]
nombre
# Out:
# [&#39;Honest Greens&#39;,
#  &#39;La Hummuseria&#39;,
#  &#39;Kuoco 360&#39;,
#  &#39;DSTAgE&#39;,
#  &#39;celicioso&#39;,
#  &#39;Vides&#39;,
#  &#39;La Primera&#39;,
#  &#39;Panod&#39;,
#  &#39;Cannibal Raw Bar&#39;,
#  &#39;Charrua&#39;,
#  &#39;Angelita Madrid&#39;,
#  &#39;Hot Now&#39;,
#  &#39;El Cafetin De Fernando VI&#39;,
#  &#39;Krachai&#39;,
#  &#39;The Brunch Club&#39;,
#  &#39;La Pescadería&#39;,
#  &#39;Ôven Mozzarella Bar&#39;,
#  &#39;Capperi Mercato Italiano&#39;,
#  &#39;Casa Hortensia&#39;,
#  &#39;La Tavernetta&#39;,
#  &#39;Bosco de Lobos&#39;,
#  &#39;Doki Doki&#39;,
#  &#39;La Colmada&#39;,
#  &#39;ORIO Fuencarral&#39;,
#  &#39;Umiko&#39;,
#  &#39;Café de la Luz&#39;,
#  &#39;TAKOS&#39;,
#  &#39;Lamucca de Almagro&#39;,
#  &#39;Pelotari&#39;,
#  &#39;Pez Tortilla&#39;,
#  &#39;La Cabaña Argentina&#39;,
#  &#39;Lamucca&#39;,
#  &#39;Askua barra&#39;,
#  &#39;Ojalá&#39;,
#  &#39;Raimunda&#39;,
#  &#39;La Pulpería de Victoria&#39;,
#  &#39;El Jardín Secreto de SB&#39;,
#  &#39;Alabaster&#39;,
#  &#39;Habanera&#39;,
#  &#39;Cafe Angelica&#39;,
#  &#39;Pontepez&#39;,
#  &#39;El Inti de Oro&#39;,
#  &#39;Bacoa&#39;,
#  &#39;Aarde&#39;,
#  &#39;Mu! El placer de la carne&#39;,
#  &#39;Canalla Bistro by Ricard Camarena&#39;,
#  &#39;New York Burger&#39;,
#  &#39;VEGA&#39;,
#  &#39;Chilling Café&#39;,
#  &#39;99 Sushi Bar&#39;,
#  &#39;Ten Con Ten&#39;,
#  &#39;Rosi La Loca&#39;,
#  &#39;InClan Brutal Bar&#39;,
#  &#39;El Paraguas&#39;,
#  &#39;tuk tuk&#39;,
#  &#39;Eat Is Wok&#39;,
#  &#39;Fellina&#39;,
#  &#39;La Fondue De Tell&#39;,
#  &#39;Casa Pueblo&#39;,
#  &#39;Carmencita&#39;,
#  &#39;Casa Federica&#39;,
#  &#39;StreetXO&#39;,
#  &#39;Amazónico&#39;,
#  &#39;Restaurante Lily&#39;,
#  &#39;Restaurante Viva Madrid&#39;,
#  &#39;La Maquina Jorge Juan&#39;,
#  &#39;Casa Labra&#39;,
#  &#39;Arrocería Marina Ventura&#39;,
#  &#39;Asador de Aranda&#39;,
#  &#39;Ferpal&#39;,
#  &#39;Casa Jaguar&#39;,
#  &#39;Musashi&#39;,
#  &#39;Casa Dani&#39;,
#  &#39;Tepic&#39;,
#  &#39;La Gringa&#39;,
#  &#39;Vinoteca Moratín&#39;,
#  &#39;Casa Lafu&#39;,
#  &#39;Ferreteria By Ego&#39;,
#  &#39;Trattoria Malatesta&#39;,
#  &#39;Plenti&#39;,
#  &#39;La Dichosa&#39;,
#  &#39;El Perro y La Galleta&#39;,
#  &#39;Platea Madrid&#39;,
#  &#39;Kabuki Wellington&#39;,
#  &#39;La Bien Aparecida&#39;,
#  &#39;Yoka Loka&#39;,
#  &#39;Yakitoro&#39;,
#  &#39;Restaurante Bacira&#39;,
#  &#39;La Sanabresa&#39;,
#  &#39;El Mollete&#39;,
#  &#39;GramaBar&#39;,
#  &#39;La Tragantúa&#39;,
#  &#39;Delish Vegan Doughnuts&#39;,
#  &#39;Salón Cascabel&#39;,
#  &#39;La Esperanza&#39;,
#  &#39;El Senador&#39;,
#  &#39;El Sur&#39;,
#  &#39;MORE&#39;,
#  &#39;El Cielo&#39;,
#  &#39;Federal Café&#39;]

# %%
latitud = [elem2['venue']['location']['lat'] for elem2 in data["response"]['groups'][0]["items"]]
latitud
# Out:
# [40.42487975679924,
#  40.423474938716694,
#  40.421841757,
#  40.42472945683953,
#  40.4221118727551,
#  40.42101652377878,
#  40.41918268290716,
#  40.42196050145854,
#  40.42250153573088,
#  40.422416,
#  40.42034282975544,
#  40.421317,
#  40.42484543685317,
#  40.425341641247975,
#  40.42161192764877,
#  40.42288279065907,
#  40.41924524133954,
#  40.42590349266851,
#  40.423896111,
#  40.42607635914717,
#  40.424150785649374,
#  40.42116858895287,
#  40.42547618019526,
#  40.423747918148486,
#  40.417593886155295,
#  40.42212279165881,
#  40.418938,
#  40.42821006735003,
#  40.42222852507288,
#  40.4242382067626,
#  40.415696026060175,
#  40.423160346582144,
#  40.417066970177565,
#  40.42539107275883,
#  40.420203,
#  40.416506381,
#  40.419106710663684,
#  40.41807931218255,
#  40.42548355338372,
#  40.423226309929944,
#  40.42377716955972,
#  40.415750765,
#  40.416697729325435,
#  40.419701,
#  40.4194765313818,
#  40.426057373983376,
#  40.42212085931879,
#  40.42231841389461,
#  40.42201400548159,
#  40.42659511541311,
#  40.427880944967086,
#  40.415821011717526,
#  40.41502338061646,
#  40.42386542247894,
#  40.429852012854724,
#  40.41555287654177,
#  40.430752,
#  40.42769210185809,
#  40.41461381230456,
#  40.426141864460845,
#  40.42398175672907,
#  40.427687702735966,
#  40.42383753262332,
#  40.42311435242576,
#  40.41516746717612,
#  40.42382256919969,
#  40.41715,
#  40.41535302116083,
#  40.419858642235255,
#  40.417045824676954,
#  40.4190188,
#  40.41900048005936,
#  40.427095859479174,
#  40.42791209134333,
#  40.42617843445485,
#  40.41261947884343,
#  40.42210378363954,
#  40.412558,
#  40.416788,
#  40.41213451312291,
#  40.42652303865942,
#  40.420445,
#  40.426083288964996,
#  40.42189124807032,
#  40.42392365126327,
#  40.41161458501999,
#  40.419647701387746,
#  40.433803250381146,
#  40.41256047164362,
#  40.419912891328146,
#  40.41976873108436,
#  40.41184555400155,
#  40.42694912512703,
#  40.427699920608354,
#  40.41149716350271,
#  40.42076966674159,
#  40.411135324189495,
#  40.42388443976496,
#  40.4124737354003,
#  40.427173427148695]

# %%
longitud = [elem3['venue']['location']['lng'] for elem3 in data["response"]['groups'][0]["items"]]
longitud
# Out:
# [-3.697894121919185,
#  -3.700036508653173,
#  -3.698455902,
#  -3.6963052685894597,
#  -3.695725917401657,
#  -3.6973542003338395,
#  -3.697793514240437,
#  -3.6954788629561257,
#  -3.694248172533777,
#  -3.693999,
#  -3.700391295468739,
#  -3.69803,
#  -3.6957562579032963,
#  -3.6962992873730958,
#  -3.7027903662919144,
#  -3.7032084227445803,
#  -3.6978500877927485,
#  -3.6971252798566607,
#  -3.700424408,
#  -3.6941559395385597,
#  -3.6990139940797278,
#  -3.689797446212131,
#  -3.7043642238817385,
#  -3.70071716655042,
#  -3.6973123468602287,
#  -3.7025909845617453,
#  -3.703748,
#  -3.695088992676898,
#  -3.6907204539990075,
#  -3.706568309829162,
#  -3.6989742057930957,
#  -3.7040597217866043,
#  -3.698627286195405,
#  -3.7040164965431708,
#  -3.692069,
#  -3.70170887,
#  -3.7023069232360086,
#  -3.689794959957802,
#  -3.6913277741268846,
#  -3.707465329347798,
#  -3.7054651587022125,
#  -3.698969495,
#  -3.7016824585888597,
#  -3.689125,
#  -3.7038851050383497,
#  -3.688617396245811,
#  -3.6907109051907323,
#  -3.7060473848532434,
#  -3.706108026089968,
#  -3.6888195991425463,
#  -3.6884764005263433,
#  -3.7029546044326276,
#  -3.7018643661445174,
#  -3.685813532393988,
#  -3.701580219391873,
#  -3.700304794194268,
#  -3.694272,
#  -3.7041432264886596,
#  -3.6985981117031463,
#  -3.7073716314199663,
#  -3.7087566565709693,
#  -3.687255526702393,
#  -3.6850245572738443,
#  -3.709037008777121,
#  -3.6998336282593405,
#  -3.686157243920154,
#  -3.7045143,
#  -3.6989406886968395,
#  -3.7075824775498614,
#  -3.7057418628089156,
#  -3.7085157,
#  -3.7076562433548195,
#  -3.6857193669863895,
#  -3.687806554183616,
#  -3.707859523116006,
#  -3.695511165213914,
#  -3.7093506336068813,
#  -3.699631,
#  -3.707182,
#  -3.696623656621767,
#  -3.7097822842636523,
#  -3.687342,
#  -3.68866416486341,
#  -3.6842165091037944,
#  -3.6869895666812744,
#  -3.698692811574475,
#  -3.697201837743589,
#  -3.6990506779000705,
#  -3.6984811188512157,
#  -3.710502973556587,
#  -3.7071476250900037,
#  -3.6954076239854836,
#  -3.7100989203246573,
#  -3.6872659298342922,
#  -3.6994495684985402,
#  -3.7114585151950705,
#  -3.699521331741858,
#  -3.6838091221418963,
#  -3.6956884720810095,
#  -3.7092873110522837]

# %%
direccion = [elem4['venue']['location']['formattedAddress'] for elem4 in data["response"]['groups'][0]["items"]]
direccion
# Out:
# [[&#39;Calle Hortaleza 100&#39;, &#39;28004 Madrid Madrid&#39;, &#39;España&#39;],
#  [&#39;C. Hernán Cortés, 8&#39;, &#39;28004 Madrid Madrid&#39;, &#39;España&#39;],
#  [&#39;Calle San Bartolmé, 14&#39;, &#39;28004 Madrid Madrid&#39;, &#39;España&#39;],
#  [&#39;C. Regueros, 8&#39;, &#39;28004 Madrid Madrid&#39;, &#39;España&#39;],
#  [&#39;Calle del Barquillo 19&#39;, &#39;28004 Madrid Madrid&#39;, &#39;España&#39;],
#  [&#39;C. Libertad, 12&#39;, &#39;28004 Madrid Madrid&#39;, &#39;España&#39;],
#  [&#39;Gran Vía, 1&#39;, &#39;28013 Madrid Madrid&#39;, &#39;España&#39;],
#  [&#39;Calle Prim 1&#39;, &#39;28004 Madrid Madrid&#39;, &#39;España&#39;],
#  [&#39;Calle Almirante 12 (Calle Conde de Xiquena)&#39;,
#   &#39;28004 Madrid Madrid&#39;,
#   &#39;España&#39;],
#  [&#39;28004 Madrid Madrid&#39;, &#39;España&#39;],
#  [&#39;C. Reina, 4&#39;, &#39;28004 Madrid Madrid&#39;, &#39;España&#39;],
#  [&#39;barbieri 14&#39;, &#39;28004 Madrid Madrid&#39;, &#39;España&#39;],
#  [&#39;Fernando VI&#39;, &#39;Madrid Madrid&#39;, &#39;España&#39;],
#  [&#39;C. Fernando VI, 11&#39;, &#39;28004 Madrid Madrid&#39;, &#39;España&#39;],
#  [&#39;Calle del barco 25&#39;, &#39;28004 Madrid Madrid&#39;, &#39;España&#39;],
#  [&#39;C. Ballesta, 32&#39;, &#39;28004 Madrid Madrid&#39;, &#39;España&#39;],
#  [&#39;Calle Gran Via, 6&#39;, &#39;28013 Madrid Madrid&#39;, &#39;España&#39;],
#  [&#39;C/ Fernando VI 2&#39;, &#39;Madrid Madrid&#39;, &#39;España&#39;],
#  [&#39;Calle de la Farmacia, 2, 3&#39;, &#39;28004 Madrid Madrid&#39;, &#39;España&#39;],
#  [&#39;C. Orellana, 17&#39;, &#39;28004 Madrid Madrid&#39;, &#39;España&#39;],
#  [&#39;C. Hortaleza, 63 (C. Farmacia)&#39;, &#39;28004 Madrid Madrid&#39;, &#39;España&#39;],
#  [&#39;Calle Villalar, 4&#39;, &#39;28001 Madrid Madrid&#39;, &#39;España&#39;],
#  [&#39;19 Calle del Espíritu Santo&#39;, &#39;28004 Madrid Madrid&#39;, &#39;España&#39;],
#  [&#39;C. Fuencarral, 49 (C. Colón)&#39;, &#39;28043 Madrid Madrid&#39;, &#39;España&#39;],
#  [&#39;Los Madrazo 18&#39;, &#39;Madrid Madrid&#39;, &#39;España&#39;],
#  [&#39;C. de la Puebla, 8 (Calle Del Barco)&#39;, &#39;28004 Madrid Madrid&#39;, &#39;España&#39;],
#  [&#39;C. Abada, 2&#39;, &#39;28013 Madrid Madrid&#39;, &#39;España&#39;],
#  [&#39;C. Almagro, 3&#39;, &#39;28010 Madrid Madrid&#39;, &#39;España&#39;],
#  [&#39;P. de Recoletos, 3&#39;, &#39;28001 Madrid Madrid&#39;, &#39;España&#39;],
#  [&#39;C. Pez, 36&#39;, &#39;28004 Madrid Madrid&#39;, &#39;España&#39;],
#  [&#39;C. Ventura de la Vega, 10 (C. Carrera de San Jerónimo)&#39;,
#   &#39;28014 Madrid Madrid&#39;,
#   &#39;España&#39;],
#  [&#39;Pl. de Carlos Cambronero 4 (C. Pez)&#39;, &#39;28004 Madrid Madrid&#39;, &#39;España&#39;],
#  [&#39;Calle Arlabán 7&#39;, &#39;28014 Madrid Madrid&#39;, &#39;España&#39;],
#  [&#39;C. San Andrés, 1&#39;, &#39;28004 Madrid Madrid&#39;, &#39;España&#39;],
#  [&#39;28001 Madrid Madrid&#39;, &#39;España&#39;],
#  [&#39;Calle de La Victoria, 2, (Junto a Puerta del Sol) (Carrera de San Jerónimo)&#39;,
#   &#39;28012 Madrid Madrid&#39;,
#   &#39;España&#39;],
#  [&#39;C. Montera, 37 - 4ª Planta&#39;, &#39;28013 Madrid Madrid&#39;, &#39;España&#39;],
#  [&#39;C. Montalbán, 9&#39;, &#39;28014 Madrid Madrid&#39;, &#39;España&#39;],
#  [&#39;Calle de Génova, 28&#39;, &#39;28004 Madrid Madrid&#39;, &#39;España&#39;],
#  [&#39;C/ San Bernardo 24 (C/ la Luna)&#39;, &#39;28015 Madrid Madrid&#39;, &#39;España&#39;],
#  [&#39;Pez, 18 (Calle Pizarro)&#39;, &#39;28004 Madrid Madrid&#39;, &#39;España&#39;],
#  [&#39;Calle VENTURA DE LA VEGA, 12&#39;, &#39;28014 Madrid Madrid&#39;, &#39;España&#39;],
#  [&#39;Carrera de San Jerónimo, 3&#39;, &#39;28014 Madrid Centro Madrid&#39;, &#39;España&#39;],
#  [&#39;28014 Madrid Madrid&#39;, &#39;España&#39;],
#  [&#39;Calle de Chinchilla, 3 (Gran Vía)&#39;, &#39;28013 Madrid Madrid&#39;, &#39;España&#39;],
#  [&#39;C. Goya, 5-7, Planta 1&#39;, &#39;28001 Madrid Madrid&#39;, &#39;España&#39;],
#  [&#39;Calle de Recoletos, 4&#39;, &#39;28004 Madrid Madrid&#39;, &#39;España&#39;],
#  [&#39;C/ Luna, 9&#39;, &#39;28004 Madrid Madrid&#39;, &#39;España&#39;],
#  [&#39;Calle Estrella, 5&#39;, &#39;Madrid Madrid&#39;, &#39;España&#39;],
#  [&#39;C. Hermosilla, 4 (P.  de la Castellana)&#39;, &#39;28001 Madrid Madrid&#39;, &#39;España&#39;],
#  [&#39;C. Ayala, 6 (P. de la Castellana)&#39;, &#39;28001 Madrid Madrid&#39;, &#39;España&#39;],
#  [&#39;Calle Cadiz 4&#39;, &#39;28012 Madrid Madrid&#39;, &#39;España&#39;],
#  [&#39;Calle de Álvarez Gato, 4&#39;, &#39;28012 Madrid Madrid&#39;, &#39;España&#39;],
#  [&#39;C. Jorge Juan, 16&#39;, &#39;28006 Madrid Madrid&#39;, &#39;España&#39;],
#  [&#39;C. Cardenal Cisneros 6&#39;, &#39;28010 Madrid Madrid&#39;, &#39;España&#39;],
#  [&#39;C/príncipe 15&#39;, &#39;28012 Madrid Madrid&#39;, &#39;España&#39;],
#  [&#39;Caracas 21&#39;, &#39;28010 Madrid Madrid&#39;, &#39;España&#39;],
#  [&#39;C. Divino Pastor, 12&#39;, &#39;28004 Madrid Madrid&#39;, &#39;España&#39;],
#  [&#39;Leon 3&#39;, &#39;28014 Madrid Madrid&#39;, &#39;España&#39;],
#  [&#39;C. San Vicente Ferrer, 51&#39;, &#39;28015 Madrid Madrid&#39;, &#39;España&#39;],
#  [&#39;C. Manzana, 19 (C. del Alamo)&#39;, &#39;28015 Madrid Madrid&#39;, &#39;España&#39;],
#  [&#39;C. Serrano, 52&#39;, &#39;28001 Madrid Madrid&#39;, &#39;España&#39;],
#  [&#39;C. Jorge Juan, 20&#39;, &#39;28001 Madrid Madrid&#39;, &#39;España&#39;],
#  [&#39;Mercado de los Mostenses (Pza. Mostenses 1)&#39;,
#   &#39;28015 Madrid Madrid&#39;,
#   &#39;España&#39;],
#  [&#39;C. Manuel Fernández y González, 7&#39;, &#39;28014 Madrid Madrid&#39;, &#39;España&#39;],
#  [&#39;C. Jorge Juan, 12&#39;, &#39;Madrid Madrid&#39;, &#39;España&#39;],
#  [&#39;C. Tetuán, 12&#39;, &#39;28013 Madrid Madrid&#39;, &#39;España&#39;],
#  [&#39;C. Ventura de la Vega, 13 (Carrera de San Jerónimo)&#39;,
#   &#39;28014 Madrid Madrid&#39;,
#   &#39;España&#39;],
#  [&#39;C. Preciados, 44&#39;, &#39;28008 Madrid Madrid&#39;, &#39;España&#39;],
#  [&#39;C. Arenal&#39;, &#39;28013 Madrid Madrid&#39;, &#39;España&#39;],
#  [&#39;Calle de los Caños del Peral 9&#39;, &#39;28013 Madrid Madrid&#39;, &#39;España&#39;],
#  [&#39;C. de las Conchas, 4&#39;, &#39;28013 Madrid Madrid&#39;, &#39;España&#39;],
#  [&#39;C. Ayala, 28&#39;, &#39;28001 Madrid Madrid&#39;, &#39;España&#39;],
#  [&#39;Calle de Ayala 14&#39;, &#39;28001 Madrid Madrid&#39;, &#39;España&#39;],
#  [&#39;C. San Vicente Ferrer, 57&#39;, &#39;28015 Madrid Madrid&#39;, &#39;España&#39;],
#  [&#39;C. Moratín, 36&#39;, &#39;28014 Madrid Madrid&#39;, &#39;España&#39;],
#  [&#39;Calle Flor Baja, 1&#39;, &#39;28013 Madrid Madrid&#39;, &#39;España&#39;],
#  [&#39;57 Calle de Atocha&#39;, &#39;28012 Madrid Madrid&#39;, &#39;España&#39;],
#  [&#39;C. Coloreros, 5 (C. Mayor)&#39;, &#39;28013 Madrid Madrid&#39;, &#39;España&#39;],
#  [&#39;Costanilla de los Desamparados, 13&#39;, &#39;28014 Madrid Madrid&#39;, &#39;España&#39;],
#  [&#39;C. Bernardo Lopez Garcia, 11&#39;, &#39;28015 Madrid Madrid&#39;, &#39;España&#39;],
#  [&#39;Calle de Claudio Coello, 1&#39;, &#39;28009 Madrid Madrid&#39;, &#39;España&#39;],
#  [&#39;C. Goya, 5-7&#39;, &#39;28001 Madrid Madrid&#39;, &#39;España&#39;],
#  [&#39;Hotel Wellington (C. Velázquez, 6)&#39;, &#39;28001 Madrid Madrid&#39;, &#39;España&#39;],
#  [&#39;Calle de Jorge Juan, 8&#39;, &#39;28001 Madrid Madrid&#39;, &#39;España&#39;],
#  [&#39;C. Santa Isabel, 5 (mercado de Antón Martín,  pto. 81 planta baja)&#39;,
#   &#39;28012 Madrid Madrid&#39;,
#   &#39;España&#39;],
#  [&#39;C. de la Reina, 41&#39;, &#39;28001 Madrid Madrid&#39;, &#39;España&#39;],
#  [&#39;Castillo, 16 (Sagunto)&#39;, &#39;28010 Madrid Madrid&#39;, &#39;España&#39;],
#  [&#39;C. Amor de Dios, 4&#39;, &#39;28014 Madrid Madrid&#39;, &#39;España&#39;],
#  [&#39;C. La Bola, 4&#39;, &#39;28013 Madrid Madrid&#39;, &#39;España&#39;],
#  [&#39;C. Preciados, 40&#39;, &#39;28013 Madrid Madrid&#39;, &#39;España&#39;],
#  [&#39;C. Verónica, 4 (C. Fúcar)&#39;, &#39;28014 Madrid Madrid&#39;, &#39;España&#39;],
#  [&#39;3 Calle del Cristo&#39;, &#39;28015 Madrid Madrid&#39;, &#39;España&#39;],
#  [&#39;Serrano 52, 7 planta (Ayala)&#39;, &#39;28001 Madrid Centro Madrid&#39;, &#39;España&#39;],
#  [&#39;C. Torrecilla del Leal, 3&#39;, &#39;28012 Madrid Madrid&#39;, &#39;España&#39;],
#  [&#39;Plaza de La Marina Española, 2&#39;, &#39;28013 Madrid Madrid&#39;, &#39;España&#39;],
#  [&#39;C. Torrecilla del Leal, 12&#39;, &#39;28012 Madrid Madrid&#39;, &#39;España&#39;],
#  [&#39;Jorge Juan,25 (Velázquez)&#39;, &#39;28001 Madrid Madrid&#39;, &#39;España&#39;],
#  [&#39;Calle Fúcar, 4&#39;, &#39;28014 Madrid Madrid&#39;, &#39;España&#39;],
#  [&#39;Pl. de las Comendadoras, 9 (C. Amaniel, 30)&#39;,
#   &#39;28015 Madrid Madrid&#39;,
#   &#39;España&#39;]]

# %%
BBDD = {'Restaurant': nombre, 'Address':direccion, 'latitude':latitud, 'lomgitude':longitud}

# %%
df = pd.DataFrame(BBDD)
df
# Out:
#        Restaurant                                            Address  \
# 0   Honest Greens  [Calle Hortaleza 100, 28004 Madrid Madrid, Esp...
# 1   La Hummuseria  [C. Hernán Cortés, 8, 28004 Madrid Madrid, Esp...
# 2       Kuoco 360  [Calle San Bartolmé, 14, 28004 Madrid Madrid, ...
# 3          DSTAgE      [C. Regueros, 8, 28004 Madrid Madrid, España]
# 4       celicioso  [Calle del Barquillo 19, 28004 Madrid Madrid, ...
# ..            ...                                                ...
# 95     El Senador  [Plaza de La Marina Española, 2, 28013 Madrid ...
# 96         El Sur  [C. Torrecilla del Leal, 12, 28012 Madrid Madr...
# 97           MORE  [Jorge Juan,25 (Velázquez), 28001 Madrid Madri...
# 98       El Cielo      [Calle Fúcar, 4, 28014 Madrid Madrid, España]
# 99   Federal Café  [Pl. de las Comendadoras, 9 (C. Amaniel, 30), ...
#
#      latitude  lomgitude
# 0   40.424880  -3.697894
# 1   40.423475  -3.700037
# 2   40.421842  -3.698456
# 3   40.424729  -3.696305
# 4   40.422112  -3.695726
# ..        ...        ...
# 95  40.420770  -3.711459
# 96  40.411135  -3.699521
# 97  40.423884  -3.683809
# 98  40.412474  -3.695688
# 99  40.427173  -3.709287
#
# [100 rows x 4 columns]

# %% [markdown]
# Pruebo que el json de los restaurantes de Chueca es correcto

# %%
df_R_Chueca = pd.read_json("restaurants_Chueca.json")
df_R_Chueca
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# &lt;ipython-input-5-06a1866c3306&gt; in &lt;module&gt;
# ----&gt; 1 df_R_Chueca = pd.read_json(&quot;restaurants_Chueca.json&quot;)
#       2 df_R_Chueca
#
# ~\AppData\Roaming\Python\Python38\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     197                 else:
#     198                     kwargs[new_arg_name] = new_arg_value
# --&gt; 199             return func(*args, **kwargs)
#     200
#     201         return cast(F, wrapper)
#
# ~\AppData\Roaming\Python\Python38\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     294                 )
#     295                 warnings.warn(msg, FutureWarning, stacklevel=stacklevel)
# --&gt; 296             return func(*args, **kwargs)
#     297
#     298         return wrapper
#
# ~\AppData\Roaming\Python\Python38\site-packages\pandas\io\json\_json.py in read_json(path_or_buf, orient, typ, dtype, convert_axes, convert_dates, keep_default_dates, numpy, precise_float, date_unit, encoding, lines, chunksize, compression, nrows)
#     616         return json_reader
#     617
# --&gt; 618     result = json_reader.read()
#     619     if should_close:
#     620         filepath_or_buffer.close()
#
# ~\AppData\Roaming\Python\Python38\site-packages\pandas\io\json\_json.py in read(self)
#     753                 obj = self._get_object_parser(self._combine_lines(data))
#     754         else:
# --&gt; 755             obj = self._get_object_parser(self.data)
#     756         self.close()
#     757         return obj
#
# ~\AppData\Roaming\Python\Python38\site-packages\pandas\io\json\_json.py in _get_object_parser(self, json)
#     775         obj = None
#     776         if typ == &quot;frame&quot;:
# --&gt; 777             obj = FrameParser(json, **kwargs).parse()
#     778
#     779         if typ == &quot;series&quot; or obj is None:
#
# ~\AppData\Roaming\Python\Python38\site-packages\pandas\io\json\_json.py in parse(self)
#     884
#     885         else:
# --&gt; 886             self._parse_no_numpy()
#     887
#     888         if self.obj is None:
#
# ~\AppData\Roaming\Python\Python38\site-packages\pandas\io\json\_json.py in _parse_no_numpy(self)
#    1116
#    1117         if orient == &quot;columns&quot;:
# -&gt; 1118             self.obj = DataFrame(
#    1119                 loads(json, precise_float=self.precise_float), dtype=None
#    1120             )
#
# ~\AppData\Roaming\Python\Python38\site-packages\pandas\core\frame.py in __init__(self, data, index, columns, dtype, copy)
#     527         else:
#     528             if index is None or columns is None:
# --&gt; 529                 raise ValueError(&quot;DataFrame constructor not properly called!&quot;)
#     530
#     531             if not dtype:
#
# ValueError: DataFrame constructor not properly called!

# %%
df_R_Chueca = pd.read_json("rest_Chueca.json")
df_R_Chueca
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# &lt;ipython-input-8-585e6673f344&gt; in &lt;module&gt;
# ----&gt; 1 pd.read_json(&quot;rest_Chueca.json&quot;)
#
# ~\AppData\Roaming\Python\Python38\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     197                 else:
#     198                     kwargs[new_arg_name] = new_arg_value
# --&gt; 199             return func(*args, **kwargs)
#     200
#     201         return cast(F, wrapper)
#
# ~\AppData\Roaming\Python\Python38\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     294                 )
#     295                 warnings.warn(msg, FutureWarning, stacklevel=stacklevel)
# --&gt; 296             return func(*args, **kwargs)
#     297
#     298         return wrapper
#
# ~\AppData\Roaming\Python\Python38\site-packages\pandas\io\json\_json.py in read_json(path_or_buf, orient, typ, dtype, convert_axes, convert_dates, keep_default_dates, numpy, precise_float, date_unit, encoding, lines, chunksize, compression, nrows)
#     616         return json_reader
#     617
# --&gt; 618     result = json_reader.read()
#     619     if should_close:
#     620         filepath_or_buffer.close()
#
# ~\AppData\Roaming\Python\Python38\site-packages\pandas\io\json\_json.py in read(self)
#     753                 obj = self._get_object_parser(self._combine_lines(data))
#     754         else:
# --&gt; 755             obj = self._get_object_parser(self.data)
#     756         self.close()
#     757         return obj
#
# ~\AppData\Roaming\Python\Python38\site-packages\pandas\io\json\_json.py in _get_object_parser(self, json)
#     775         obj = None
#     776         if typ == &quot;frame&quot;:
# --&gt; 777             obj = FrameParser(json, **kwargs).parse()
#     778
#     779         if typ == &quot;series&quot; or obj is None:
#
# ~\AppData\Roaming\Python\Python38\site-packages\pandas\io\json\_json.py in parse(self)
#     884
#     885         else:
# --&gt; 886             self._parse_no_numpy()
#     887
#     888         if self.obj is None:
#
# ~\AppData\Roaming\Python\Python38\site-packages\pandas\io\json\_json.py in _parse_no_numpy(self)
#    1116
#    1117         if orient == &quot;columns&quot;:
# -&gt; 1118             self.obj = DataFrame(
#    1119                 loads(json, precise_float=self.precise_float), dtype=None
#    1120             )
#
# ~\AppData\Roaming\Python\Python38\site-packages\pandas\core\frame.py in __init__(self, data, index, columns, dtype, copy)
#     527         else:
#     528             if index is None or columns is None:
# --&gt; 529                 raise ValueError(&quot;DataFrame constructor not properly called!&quot;)
#     530
#     531             if not dtype:
#
# ValueError: DataFrame constructor not properly called!
